# %% [markdown]
# <a href="https://colab.research.google.com/github/TaicirCheikhrouhou/aerl-tests/blob/main/AE_RL_NSl_KDDaugmented.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.0).
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

taicircheikhrouhou_nsl_kdd_augmented_path = kagglehub.dataset_download('taicircheikhrouhou/nsl-kdd-augmented')

print('Data source import complete.')
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/taicircheikhrouhou/nsl-kdd-augmented?dataset_version_number=2...
# 100%|██████████| 23.3M/23.3M [00:00<00:00, 52.3MB/s]
# Extracting files...
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K
import json
from sklearn.utils import shuffle
import os
import sys
import time

# %%
class data_cls:
    def __init__(self,train_test,**kwargs):
        col_names = ["duration","protocol_type","service","flag","src_bytes",
            "dst_bytes","land_f","wrong_fragment","urgent","hot","num_failed_logins",
            "logged_in","num_compromised","root_shell","su_attempted","num_root",
            "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
            "is_host_login","is_guest_login","count","srv_count","serror_rate",
            "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
            "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
            "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
            "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
            "dst_host_rerror_rate","dst_host_srv_rerror_rate","labels","dificulty"]
        self.index = 0
        # Data formated path and test path.
        self.loaded = False
        self.train_test = train_test
        self.train_path = kwargs.get('train_path', '/kaggle/input/nsl-kdd-augmented/KDDTrain_FINAL.txt')
        self.test_path = kwargs.get('test_path',
                                    'https://raw.githubusercontent.com/gcamfer/Anomaly-ReactionRL/master/datasets/NSL/KDDTest%2B.txt')

        self.formated_train_path = kwargs.get('formated_train_path',
                                              "formated_train_adv.data")
        self.formated_test_path = kwargs.get('formated_test_path',
                                             "formated_test_adv.data")

        self.attack_types = ['normal','DoS','Probe','R2L']
        self.attack_names = []
        self.attack_map =   { 'normal': 'normal',

                        'back': 'DoS',
                        'land': 'DoS',
                        'neptune': 'DoS',
                        'pod': 'DoS',
                        'smurf': 'DoS',
                        'teardrop': 'DoS',
                        'mailbomb': 'DoS',
                        'apache2': 'DoS',
                        'processtable': 'DoS',
                        'udpstorm': 'DoS',

                        'ipsweep': 'Probe',
                        'nmap': 'Probe',
                        'portsweep': 'Probe',
                        'satan': 'Probe',
                        'mscan': 'Probe',
                        'saint': 'Probe',

                        'ftp_write': 'R2L',
                        'guess_passwd': 'R2L',
                        'imap': 'R2L',
                        'multihop': 'R2L',
                        'phf': 'R2L',
                        'spy': 'R2L',
                        'warezclient': 'R2L',
                        'warezmaster': 'R2L',
                        'sendmail': 'R2L',
                        'named': 'R2L',
                        'snmpgetattack': 'R2L',
                        'snmpguess': 'R2L',
                        'xlock': 'R2L',
                        'xsnoop': 'R2L',
                        'worm': 'R2L'
                    }
        self.all_attack_names = list(self.attack_map.keys())

        formated = False

        # Test formated data exists
        if os.path.exists(self.formated_train_path) and os.path.exists(self.formated_test_path):
            formated = True

        self.formated_dir = "../datasets/formated/"
        if not os.path.exists(self.formated_dir):
            os.makedirs(self.formated_dir)


        # If it does not exist, it's needed to format the data
        if not formated:
            ''' Formating the dataset for ready-2-use data'''
            self.df = pd.read_csv(self.train_path,sep=',',names=col_names,index_col=False)
            if 'dificulty' in self.df.columns:
                self.df.drop('dificulty', axis=1, inplace=True) #in case of difficulty

            data2 = pd.read_csv(self.test_path,sep=',',names=col_names,index_col=False)
            if 'dificulty' in data2:
                del(data2['dificulty'])
            train_indx = self.df.shape[0]
            frames = [self.df,data2]
            self.df = pd.concat(frames)

            # Dataframe processing
            self.df = pd.concat([self.df.drop('protocol_type', axis=1), pd.get_dummies(self.df['protocol_type'])], axis=1)
            self.df = pd.concat([self.df.drop('service', axis=1), pd.get_dummies(self.df['service'])], axis=1)
            self.df = pd.concat([self.df.drop('flag', axis=1), pd.get_dummies(self.df['flag'])], axis=1)

            # 1 if ``su root'' command attempted; 0 otherwise
            self.df['su_attempted'] = self.df['su_attempted'].replace(2.0, 0.0)

             # One hot encoding for labels
            self.df = pd.concat([self.df.drop('labels', axis=1),
                            pd.get_dummies(self.df['labels'])], axis=1)


            # Normalization of the df
            #normalized_df=(df-df.mean())/df.std()
            for indx,dtype in self.df.dtypes.items():
                if dtype == 'float64' or dtype == 'int64':
                    if self.df[indx].max() == 0 and self.df[indx].min()== 0:
                        self.df[indx] = 0
                    else:
                        self.df[indx] = (self.df[indx]-self.df[indx].min())/(self.df[indx].max()-self.df[indx].min())


            # Save data
            test_df = self.df.iloc[train_indx:self.df.shape[0]]
            test_df = shuffle(test_df,random_state=np.random.randint(0,100))
            self.df = self.df[:train_indx]
            self.df = shuffle(self.df,random_state=np.random.randint(0,100))
            test_df.to_csv(self.formated_test_path,sep=',',index=False)
            self.df.to_csv(self.formated_train_path,sep=',',index=False)

            # Create a list with the existent attacks in the df
            for att in self.attack_map:
                if att in self.df.columns:
                # Add only if there is exist at least 1
                    if np.sum(self.df[att].values) > 1:
                        self.attack_names.append(att)

    def get_shape(self):
        if self.loaded is False:
            self._load_df()

        self.data_shape = self.df.shape
        # stata + labels
        return self.data_shape

    ''' Get n-rows from loaded data
        The dataset must be loaded in RAM
    '''
    def get_batch(self,batch_size=100):
        if self.loaded is False:
            self._load_df()

        # Read the df rows
        indexes = list(range(self.index,self.index+batch_size))
        if max(indexes)>self.data_shape[0]-1:
            dif = max(indexes)-self.data_shape[0]
            indexes[len(indexes)-dif-1:len(indexes)] = list(range(dif+1))
            self.index=batch_size-dif
            batch = self.df.iloc[indexes]
        else:
            batch = self.df.iloc[indexes]
            self.index += batch_size

        labels = batch[self.attack_names]

        batch = batch.drop(self.all_attack_names,axis=1)

        return batch,labels

    def get_full(self):
        if self.loaded is False:
            self._load_df()


        labels = self.df[self.attack_names]

        batch = self.df.drop(self.all_attack_names,axis=1)


        return batch,labels

    def _load_df(self):
        if self.train_test == 'train':
            self.df = pd.read_csv(self.formated_train_path,sep=',') # Read again the csv
        else:
            self.df = pd.read_csv(self.formated_test_path,sep=',')
        self.index=np.random.randint(0,self.df.shape[0]-1,dtype=np.int32)
        self.loaded = True
         # Create a list with the existent attacks in the df
        for att in self.attack_map:
            if att in self.df.columns:
                # Add only if there is exist at least 1
                if np.sum(self.df[att].values) > 1:
                    self.attack_names.append(att)
        #self.headers = list(self.df)

# %%
import keras
import keras.ops as ops
import keras.losses

def huber_loss(y_true, y_pred, clip_value=1.0):
    """Huber loss - robust to outliers."""
    assert clip_value > 0.
    x = y_true - y_pred
    if np.isinf(clip_value):
        return 0.5 * ops.square(x)

    condition = ops.abs(x) < clip_value
    squared_loss = 0.5 * ops.square(x)
    linear_loss = clip_value * (ops.abs(x) - 0.5 * clip_value)
    return ops.where(condition, squared_loss, linear_loss)

# Register it
keras.losses.huber_loss = huber_loss

# %%
class QNetwork():
    """
    Q-Network Estimator
    Represents the global model for the table
    """

    def __init__(self,obs_size,num_actions,hidden_size = 100,
                 hidden_layers = 1,learning_rate=.2):
        """
        Initialize the network with the provided shape
        """
        self.obs_size = obs_size
        self.num_actions = num_actions

        # Network arquitecture
        self.model = Sequential()
        # Add imput layer
        self.model.add(Dense(hidden_size, input_shape=(obs_size,),
                             activation='relu'))
        # Add hidden layers
        for layers in range(hidden_layers):
            self.model.add(Dense(hidden_size, activation='relu'))
        # Add output layer
        self.model.add(Dense(num_actions))

        #optimizer = optimizers.SGD(learning_rate)
        # optimizer = optimizers.Adam(alpha=learning_rate)
        optimizer = optimizers.Adam(0.00025)
        # optimizer = optimizers.RMSpropGraves(learning_rate, 0.95, self.momentum, 1e-2)

        # Compilation of the model with optimizer and loss
        self.model.compile(loss=keras.losses.Huber(),optimizer=optimizer)

    def predict(self,state,batch_size=1):
        """
        Predicts action values.
        """
        return self.model.predict(state,batch_size=batch_size, verbose=0)

    def update(self, states, q):
        """
        Updates the estimator with the targets.

        Args:
          states: Target states
          q: Estimated values

        Returns:
          The calculated loss on the batch.
        """
        loss = self.model.train_on_batch(states, q)
        return loss

    @staticmethod
    def copy_model(model):
        """Returns a deep copy of a keras model."""
        model.save("tmp_model.keras")  # modern save format
        return keras.models.load_model("tmp_model.keras", compile=False)

# %%
#Policy interface
class Policy:
    def __init__(self, num_actions, estimator):
        self.num_actions = num_actions
        self.estimator = estimator

class Epsilon_greedy(Policy):
    def __init__(self,estimator ,num_actions ,epsilon,min_epsilon,decay_rate, epoch_length):
        Policy.__init__(self, num_actions, estimator)
        self.name = "Epsilon Greedy"

        if (epsilon is None or epsilon < 0 or epsilon > 1):
            print("EpsilonGreedy: Invalid value of epsilon", flush = True)
            sys.exit(0)
        self.epsilon = epsilon
        self.min_epsilon = min_epsilon
        self.actions = list(range(num_actions))
        self.step_counter = 0
        self.epoch_length = epoch_length
        self.decay_rate = decay_rate

        #if epsilon is up 0.1, it will be decayed over time
        if self.epsilon > 0.01:
            self.epsilon_decay = True
        else:
            self.epsilon_decay = False

    def get_actions(self,states):
        # get next action
        if np.random.rand() <= self.epsilon:
            actions = np.random.randint(0, self.num_actions,states.shape[0])
        else:
            self.Q = self.estimator.predict(states,states.shape[0])
            actions = []
            for row in range(self.Q.shape[0]):
                best_actions = np.argwhere(self.Q[row] == np.amax(self.Q[row]))
                actions.append(best_actions[np.random.choice(len(best_actions))].item())

        self.step_counter += 1
        # decay epsilon after each epoch
        if self.epsilon_decay:
            if self.step_counter % self.epoch_length == 0:
                self.epsilon = max(self.min_epsilon, self.epsilon * self.decay_rate**self.step_counter)

        return actions

# %%
class ReplayMemory(object):
    """Implements basic replay memory"""

    def __init__(self, observation_size, max_size):
        self.observation_size = observation_size
        self.num_observed = 0
        self.max_size = max_size
        self.samples = {
                 'obs'      : np.zeros(self.max_size * 1 * self.observation_size,
                                       dtype=np.float32).reshape(self.max_size,self.observation_size),
                 'action'   : np.zeros(self.max_size * 1, dtype=np.int16).reshape(self.max_size, 1),
                 'reward'   : np.zeros(self.max_size * 1).reshape(self.max_size, 1),
                 'terminal' : np.zeros(self.max_size * 1, dtype=np.int16).reshape(self.max_size, 1),
               }

    def observe(self, state, action, reward, done):
        index = self.num_observed % self.max_size
        self.samples['obs'][index, :] = state
        self.samples['action'][index, :] = action
        self.samples['reward'][index, :] = reward
        self.samples['terminal'][index, :] = done

        self.num_observed += 1

    def sample_minibatch(self, minibatch_size):
        max_index = min(self.num_observed, self.max_size) - 1
        sampled_indices = np.random.randint(max_index, size=minibatch_size)

        s      = np.asarray(self.samples['obs'][sampled_indices, :], dtype=np.float32)
        s_next = np.asarray(self.samples['obs'][sampled_indices+1, :], dtype=np.float32)

        a      = self.samples['action'][sampled_indices].reshape(minibatch_size)
        r      = self.samples['reward'][sampled_indices].reshape((minibatch_size, 1))
        done   = self.samples['terminal'][sampled_indices].reshape((minibatch_size, 1))

        return (s, a, r, s_next, done)

# %%
'''
Reinforcement learning Agent definition
'''

class Agent(object):

    def __init__(self, actions,obs_size, policy="EpsilonGreedy", **kwargs):
        self.actions = actions
        self.num_actions = len(actions)
        self.obs_size = obs_size

        self.epsilon = kwargs.get('epsilon', 1)
        self.min_epsilon = kwargs.get('min_epsilon', .1)
        self.gamma = kwargs.get('gamma', .001)
        self.minibatch_size = kwargs.get('minibatch_size', 2)
        self.epoch_length = kwargs.get('epoch_length', 100)
        self.decay_rate = kwargs.get('decay_rate',0.99)
        self.ExpRep = kwargs.get('ExpRep',True)
        if self.ExpRep:
            self.memory = ReplayMemory(self.obs_size, kwargs.get('mem_size', 10))

        self.ddqn_time = 100
        self.ddqn_update = self.ddqn_time


        self.model_network = QNetwork(self.obs_size, self.num_actions,
                                      kwargs.get('hidden_size', 100),
                                      kwargs.get('hidden_layers',1),
                                      kwargs.get('learning_rate',.2))
        self.target_model_network = QNetwork(self.obs_size, self.num_actions,
                                      kwargs.get('hidden_size', 100),
                                      kwargs.get('hidden_layers',1),
                                      kwargs.get('learning_rate',.2))
        self.target_model_network.model = QNetwork.copy_model(self.model_network.model)

        if policy == "EpsilonGreedy":
            self.policy = Epsilon_greedy(self.model_network,len(actions),
                                         self.epsilon,self.min_epsilon,
                                         self.decay_rate,self.epoch_length)


    def learn(self, states, actions,next_states, rewards, done):
        if self.ExpRep:
            self.memory.observe(states, actions, rewards, done)
        else:
            self.states = states
            self.actions = actions
            self.next_states = next_states
            self.rewards = rewards
            self.done = done
    def update_model(self):
        if self.ExpRep:
            (states, actions, rewards, next_states, done) = self.memory.sample_minibatch(self.minibatch_size)
        else:
            states = self.states
            rewards = self.rewards
            next_states = self.next_states
            actions = self.actions
            done = self.done

        next_actions = []
        # Compute Q targets
#        Q_prime = self.model_network.predict(next_states,self.minibatch_size)
        Q_prime = self.target_model_network.predict(next_states,self.minibatch_size)
        # TODO: fix performance in this loop
        for row in range(Q_prime.shape[0]):
            best_next_actions = np.argwhere(Q_prime[row] == np.amax(Q_prime[row]))
            next_actions.append(best_next_actions[np.random.choice(len(best_next_actions))].item())
        sx = np.arange(len(next_actions))
        # Compute Q(s,a)
        Q = self.model_network.predict(states,self.minibatch_size)
        # Q-learning update
        # target = reward + gamma * max_a'{Q(next_state,next_action))}
        targets = rewards.reshape(Q[sx,actions].shape) + \
                  self.gamma * Q[sx,next_actions] * \
                  (1-done.reshape(Q[sx,actions].shape))
        Q[sx,actions] = targets

        loss = self.model_network.model.train_on_batch(states,Q)#inputs,targets

        # timer to ddqn update
        self.ddqn_update -= 1
        if self.ddqn_update == 0:
            self.ddqn_update = self.ddqn_time
#            self.target_model_network.model = QNetwork.copy_model(self.model_network.model)
            self.target_model_network.model.set_weights(self.model_network.model.get_weights())

        return loss

    def act(self, state,policy):
        raise NotImplementedError

# %%
class DefenderAgent(Agent):
    def __init__(self, actions, obs_size, policy="EpsilonGreedy", **kwargs):
        super().__init__(actions,obs_size, policy="EpsilonGreedy", **kwargs)

    def act(self,states):
        # Get actions under the policy
        actions = self.policy.get_actions(states)
        return actions

class AttackAgent(Agent):
    def __init__(self, actions, obs_size, policy="EpsilonGreedy", **kwargs):
        super().__init__(actions,obs_size, policy="EpsilonGreedy", **kwargs)

    def act(self,states):
        # Get actions under the policy
        actions = self.policy.get_actions(states)
        return actions

# %%
'''
Reinforcement learning Enviroment Definition
'''
class RLenv(data_cls):
    def __init__(self,train_test,**kwargs):
        data_cls.__init__(self,train_test,**kwargs)
        data_cls._load_df(self)
        self.data_shape = data_cls.get_shape(self)
        self.batch_size = kwargs.get('batch_size',1) # experience replay -> batch = 1
        self.iterations_episode = kwargs.get('iterations_episode',10)
        if self.batch_size=='full':
            self.batch_size = int(self.data_shape[0]/iterations_episode)


    '''
    _update_state: function to update the current state
    Returns:
        None
    Modifies the self parameters involved in the state:
        self.state and self.labels
    Also modifies the true labels to get learning knowledge
    '''
    def _update_state(self):
        self.states,self.labels = data_cls.get_batch(self)

        # Update statistics
        self.true_labels += np.sum(self.labels).values

    '''
    Returns:
        + Observation of the enviroment
    '''
    def reset(self):
        # Reset statistics
        self.def_true_labels = np.zeros(len(self.attack_types), dtype=int)
        self.def_estimated_labels = np.zeros(len(self.attack_types), dtype=int)
        self.att_true_labels = np.zeros(len(self.attack_names), dtype=int)

        self.state_numb = 0

        # Reload dataset and get a fresh batch
        data_cls._load_df(self)  # Reload and randomize index
        self.states, self.labels = data_cls.get_batch(self, self.batch_size)

        self.total_reward = 0
        self.steps_in_episode = 0

        # ✅ Return the current state as float32 numpy array
        return self.states.astype('float32').values

    '''
    Returns:
        State: Next state for the game
        Reward: Actual reward
        done: If the game ends (no end in this case)

    In the adversarial enviroment, it's only needed to return the actual reward
    '''
    def act(self,defender_actions,attack_actions):
        # Clear previous rewards
        self.att_reward = np.zeros(len(attack_actions))
        self.def_reward = np.zeros(len(defender_actions))


        attack = [self.attack_types.index(self.attack_map[self.attack_names[att]]) for att in attack_actions]

        self.def_reward = (np.asarray(defender_actions)==np.asarray(attack))*1
        self.att_reward = (np.asarray(defender_actions)!=np.asarray(attack))*1



        self.def_estimated_labels += np.bincount(defender_actions,minlength=len(self.attack_types))

        # list comprehension

        for act in attack_actions:
            self.def_true_labels[self.attack_types.index(self.attack_map[self.attack_names[act]])] += 1


        # Get new state and new true values
        attack_actions = attacker_agent.act(self.states)
        self.states = env.get_states(attack_actions)

        # Done allways false in this continuous task
        self.done = np.zeros(len(attack_actions),dtype=bool)

        return self.states, self.def_reward,self.att_reward, attack_actions, self.done

    '''
    Provide the actual states for the selected attacker actions
    Parameters:
        self:
        attacker_actions: optimum attacks selected by the attacker
            it can be one of attack_names list and select random of this
    Returns:
        State: Actual state for the selected attacks
    '''
    def get_states(self,attacker_actions):
        first = True
        for attack in attacker_actions:
            if first:
                minibatch = (self.df[self.df[self.attack_names[attack]]==1].sample(1))
                first = False
            else:
                minibatch=minibatch.append(self.df[self.df[self.attack_names[attack]]==1].sample(1))

        self.labels = minibatch[self.attack_names]
        minibatch.drop(self.all_attack_names,axis=1,inplace=True)
        self.states = minibatch

        return self.states

# %%
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(0)

# %%
if __name__ == "__main__":

    kdd_train = "/content/KDDTrain_FINAL.txt"
    kdd_test = "https://raw.githubusercontent.com/gcamfer/Anomaly-ReactionRL/master/datasets/NSL/KDDTest%2B.txt"

    formated_train_path = "formated_train_adv.data"
    formated_test_path = "formated_test_adv.data"


    # Train batch
    batch_size = 1
    # batch of memory ExpRep
    minibatch_size = 100
    ExpRep = True

    iterations_episode = 100

    # Initialization of the enviroment
    env = RLenv('train',train_path=kdd_train,test_path=kdd_test,
                formated_train_path = formated_train_path,
                formated_test_path = formated_test_path,batch_size=batch_size,
                iterations_episode=iterations_episode)
    # obs_size = size of the state
    obs_size = env.data_shape[1]-len(env.all_attack_names)

    #num_episodes = int(env.data_shape[0]/(iterations_episode)/10)
    num_episodes = 500

    '''
    Definition for the defensor agent.
    '''
    defender_valid_actions = list(range(len(env.attack_types))) # only detect type of attack
    defender_num_actions = len(defender_valid_actions)


    def_epsilon = 1 # exploration
    min_epsilon = 0.05 # min value for exploration
    def_gamma = 0.01
    def_decay_rate = 0.995

    def_hidden_size = 128
    def_hidden_layers = 3

    def_learning_rate = 0.0005

    defender_agent = DefenderAgent(defender_valid_actions,obs_size,"EpsilonGreedy",
                          epoch_length = iterations_episode,
                          epsilon = def_epsilon,
                          min_epsilon = min_epsilon,
                          decay_rate = def_decay_rate,
                          gamma = def_gamma,
                          hidden_size=def_hidden_size,
                          hidden_layers=def_hidden_layers,
                          minibatch_size = minibatch_size,
                          mem_size = 3000,
                          learning_rate=def_learning_rate,
                          ExpRep=ExpRep)
    #Pretrained defender
    #defender_agent.model_network.model.load_weights("models/type_model.h5")

    '''
    Definition for the attacker agent.
    In this case the exploration is better to be greater
    The correlation sould be greater too so gamma bigger
    '''
    attack_valid_actions = list(range(len(env.attack_names)))
    attack_num_actions = len(attack_valid_actions)

    att_epsilon = 1
    min_epsilon = 0.82 # min value for exploration

    att_gamma = 0.01
    att_decay_rate = 0.995

    att_hidden_layers = 2
    att_hidden_size = 128

    att_learning_rate = 0.0005

    attacker_agent = AttackAgent(attack_valid_actions,obs_size,"EpsilonGreedy",
                          epoch_length = iterations_episode,
                          epsilon = att_epsilon,
                          min_epsilon = min_epsilon,
                          decay_rate = att_decay_rate,
                          gamma = att_gamma,
                          hidden_size=att_hidden_size,
                          hidden_layers=att_hidden_layers,
                          minibatch_size = minibatch_size,
                          mem_size = 3000,
                          learning_rate=att_learning_rate,
                          ExpRep=ExpRep)



    # Statistics
    att_reward_chain = []
    def_reward_chain = []
    att_loss_chain = []
    def_loss_chain = []
    def_total_reward_chain = []
    att_total_reward_chain = []

	# Print parameters
    print("-------------------------------------------------------------------------------")
    print("Total epoch: {} | Iterations in epoch: {}"
          "| Minibatch from mem size: {} | Total Samples: {}|".format(num_episodes,
                         iterations_episode,minibatch_size,
                         num_episodes*iterations_episode))
    print("-------------------------------------------------------------------------------")
    print("Dataset shape: {}".format(env.data_shape))
    print("-------------------------------------------------------------------------------")
    print("Attacker parameters: Num_actions={} | gamma={} |"
          " epsilon={} | ANN hidden size={} | "
          "ANN hidden layers={}|".format(attack_num_actions,
                             att_gamma,att_epsilon, att_hidden_size,
                             att_hidden_layers))
    print("-------------------------------------------------------------------------------")
    print("Defense parameters: Num_actions={} | gamma={} | "
          "epsilon={} | ANN hidden size={} |"
          " ANN hidden layers={}|".format(defender_num_actions,
                              def_gamma,def_epsilon,def_hidden_size,
                              def_hidden_layers))
    print("-------------------------------------------------------------------------------")

    # Main loop
    attacks_by_epoch = []
    attack_labels_list = []
    for epoch in range(num_episodes):
        start_time = time.time()
        att_loss = 0.
        def_loss = 0.
        def_total_reward_by_episode = 0
        att_total_reward_by_episode = 0
        # Reset enviromet, actualize the data batch with random state/attacks
        states = env.reset()

        # Get actions for actual states following the policy
        attack_actions = attacker_agent.act(states)
        states = env.get_states(attack_actions)

        done = False

        attacks_list = []
        # Iteration in one episode
        for i_iteration in range(iterations_episode):

            attacks_list.append(attack_actions[0])
            # apply actions, get rewards and new state
            act_time = time.time()
            defender_actions = defender_agent.act(states)
            #Enviroment actuation for this actions
            next_states,def_reward, att_reward,next_attack_actions, done = env.act(defender_actions,attack_actions)
            # If the epoch*batch_size*iterations_episode is largest than the df


            attacker_agent.learn(states,attack_actions,next_states,att_reward,done)
            defender_agent.learn(states,defender_actions,next_states,def_reward,done)

            act_end_time = time.time()

            # Train network, update loss after at least minibatch_learns
            if ExpRep and epoch*iterations_episode + i_iteration >= minibatch_size:
                def_loss += defender_agent.update_model()
                att_loss += attacker_agent.update_model()
            elif not ExpRep:
                def_loss += defender_agent.update_model()
                att_loss += attacker_agent.update_model()


            update_end_time = time.time()

            # Update the state
            states = next_states
            attack_actions = next_attack_actions


            # Update statistics
            def_total_reward_by_episode += np.sum(def_reward,dtype=np.int32)
            att_total_reward_by_episode += np.sum(att_reward,dtype=np.int32)

        attacks_by_epoch.append(attacks_list)
        # Update user view
        def_reward_chain.append(def_total_reward_by_episode)
        att_reward_chain.append(att_total_reward_by_episode)
        def_loss_chain.append(def_loss)
        att_loss_chain.append(att_loss)


        end_time = time.time()
        print("\r\n|Epoch {:03d}/{:03d}| time: {:2.2f}|\r\n"
                "|Def Loss {:4.4f} | Def Reward in ep {:03d}|\r\n"
                "|Att Loss {:4.4f} | Att Reward in ep {:03d}|"
                .format(epoch, num_episodes,(end_time-start_time),
                def_loss, def_total_reward_by_episode,
                att_loss, att_total_reward_by_episode))


        print("|Def Estimated: {}| Att Labels: {}".format(env.def_estimated_labels,
              env.def_true_labels))
        attack_labels_list.append(env.def_true_labels)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# -------------------------------------------------------------------------------
# Total epoch: 500 | Iterations in epoch: 100| Minibatch from mem size: 100 | Total Samples: 50000|
# -------------------------------------------------------------------------------
# Dataset shape: (5142, 156)
# -------------------------------------------------------------------------------
# Attacker parameters: Num_actions=54 | gamma=0.01 | epsilon=1 | ANN hidden size=128 | ANN hidden layers=2|
# -------------------------------------------------------------------------------
# Defense parameters: Num_actions=4 | gamma=0.01 | epsilon=1 | ANN hidden size=128 | ANN hidden layers=3|
# -------------------------------------------------------------------------------
#
# |Epoch 000/500| time: 0.34|
# |Def Loss 0.0000 | Def Reward in ep 019|
# |Att Loss 0.0000 | Att Reward in ep 081|
# |Def Estimated: [28 31 21 20]| Att Labels: [ 4 13 30 53]
#
# |Epoch 001/500| time: 49.26|
# |Def Loss 1.2962 | Def Reward in ep 046|
# |Att Loss 0.5238 | Att Reward in ep 054|
# |Def Estimated: [13 23 22 42]| Att Labels: [ 3 18 28 51]
#
# |Epoch 002/500| time: 46.30|
# |Def Loss 0.8065 | Def Reward in ep 079|
# |Att Loss 0.2914 | Att Reward in ep 021|
# |Def Estimated: [ 7 18 21 54]| Att Labels: [ 3 15 19 63]
#
# |Epoch 003/500| time: 47.58|
# |Def Loss 0.6483 | Def Reward in ep 090|
# |Att Loss 0.2395 | Att Reward in ep 010|
# |Def Estimated: [ 4 12 27 57]| Att Labels: [ 5  8 35 52]
#
# |Epoch 004/500| time: 45.44|
# |Def Loss 0.5644 | Def Reward in ep 086|
# |Att Loss 0.2167 | Att Reward in ep 014|
# |Def Estimated: [ 4 20 29 47]| Att Labels: [ 6 18 31 45]
#
# |Epoch 005/500| time: 48.62|
# |Def Loss 0.5067 | Def Reward in ep 084|
# |Att Loss 0.2008 | Att Reward in ep 016|
# |Def Estimated: [ 5 17 28 50]| Att Labels: [ 8 16 25 51]
#
# |Epoch 006/500| time: 45.97|
# |Def Loss 0.4681 | Def Reward in ep 087|
# |Att Loss 0.1885 | Att Reward in ep 013|
# |Def Estimated: [ 3 23 25 49]| Att Labels: [10 13 29 48]
#
# |Epoch 007/500| time: 46.99|
# |Def Loss 0.4394 | Def Reward in ep 084|
# |Att Loss 0.1781 | Att Reward in ep 016|
# |Def Estimated: [ 7 20 24 49]| Att Labels: [12 11 28 49]
#
# |Epoch 008/500| time: 48.81|
# |Def Loss 0.4149 | Def Reward in ep 090|
# |Att Loss 0.1692 | Att Reward in ep 010|
# |Def Estimated: [ 4 15 26 55]| Att Labels: [ 6 13 26 55]
#
# |Epoch 009/500| time: 46.16|
# |Def Loss 0.3949 | Def Reward in ep 093|
# |Att Loss 0.1616 | Att Reward in ep 007|
# |Def Estimated: [ 6 23 28 43]| Att Labels: [ 9 23 25 43]
#
# |Epoch 010/500| time: 46.06|
# |Def Loss 0.3771 | Def Reward in ep 084|
# |Att Loss 0.1551 | Att Reward in ep 016|
# |Def Estimated: [ 7 20 27 46]| Att Labels: [ 4 16 30 50]
#
# |Epoch 011/500| time: 46.86|
# |Def Loss 0.3617 | Def Reward in ep 091|
# |Att Loss 0.1495 | Att Reward in ep 009|
# |Def Estimated: [ 8 22 33 37]| Att Labels: [ 8 21 34 37]
#
# |Epoch 012/500| time: 47.47|
# |Def Loss 0.3488 | Def Reward in ep 090|
# |Att Loss 0.1445 | Att Reward in ep 010|
# |Def Estimated: [ 3 18 30 49]| Att Labels: [ 4 16 26 54]
#
# |Epoch 013/500| time: 47.22|
# |Def Loss 0.3373 | Def Reward in ep 091|
# |Att Loss 0.1400 | Att Reward in ep 009|
# |Def Estimated: [ 6 21 28 45]| Att Labels: [ 8 17 30 45]
#
# |Epoch 014/500| time: 46.71|
# |Def Loss 0.3251 | Def Reward in ep 094|
# |Att Loss 0.1363 | Att Reward in ep 006|
# |Def Estimated: [ 7 16 28 49]| Att Labels: [ 7 18 28 47]
#
# |Epoch 015/500| time: 48.90|
# |Def Loss 0.3140 | Def Reward in ep 094|
# |Att Loss 0.1328 | Att Reward in ep 006|
# |Def Estimated: [ 8 10 31 51]| Att Labels: [ 9 10 31 50]
#
# |Epoch 016/500| time: 47.70|
# |Def Loss 0.3045 | Def Reward in ep 095|
# |Att Loss 0.1297 | Att Reward in ep 005|
# |Def Estimated: [ 9 17 23 51]| Att Labels: [10 16 23 51]
#
# |Epoch 017/500| time: 48.05|
# |Def Loss 0.2947 | Def Reward in ep 093|
# |Att Loss 0.1270 | Att Reward in ep 007|
# |Def Estimated: [12 12 24 52]| Att Labels: [ 9 16 22 53]
#
# |Epoch 018/500| time: 47.60|
# |Def Loss 0.2864 | Def Reward in ep 091|
# |Att Loss 0.1244 | Att Reward in ep 009|
# |Def Estimated: [12 15 25 48]| Att Labels: [ 9 14 28 49]
#
# |Epoch 019/500| time: 49.21|
# |Def Loss 0.2788 | Def Reward in ep 092|
# |Att Loss 0.1220 | Att Reward in ep 008|
# |Def Estimated: [12 11 35 42]| Att Labels: [ 9 12 38 41]
#
# |Epoch 020/500| time: 46.74|
# |Def Loss 0.2727 | Def Reward in ep 085|
# |Att Loss 0.1199 | Att Reward in ep 015|
# |Def Estimated: [ 7 16 35 42]| Att Labels: [ 5 12 41 42]
#
# |Epoch 021/500| time: 46.21|
# |Def Loss 0.2661 | Def Reward in ep 094|
# |Att Loss 0.1180 | Att Reward in ep 006|
# |Def Estimated: [ 8 17 25 50]| Att Labels: [ 6 17 24 53]
#
# |Epoch 022/500| time: 48.13|
# |Def Loss 0.2604 | Def Reward in ep 092|
# |Att Loss 0.1161 | Att Reward in ep 008|
# |Def Estimated: [12 27 25 36]| Att Labels: [14 24 26 36]
#
# |Epoch 023/500| time: 49.32|
# |Def Loss 0.2544 | Def Reward in ep 093|
# |Att Loss 0.1144 | Att Reward in ep 007|
# |Def Estimated: [12 18 24 46]| Att Labels: [ 9 19 23 49]
#
# |Epoch 024/500| time: 47.87|
# |Def Loss 0.2488 | Def Reward in ep 096|
# |Att Loss 0.1128 | Att Reward in ep 004|
# |Def Estimated: [ 5 11 34 50]| Att Labels: [ 5 12 37 46]
#
# |Epoch 025/500| time: 47.63|
# |Def Loss 0.2434 | Def Reward in ep 092|
# |Att Loss 0.1113 | Att Reward in ep 008|
# |Def Estimated: [14 18 23 45]| Att Labels: [15 14 23 48]
#
# |Epoch 026/500| time: 49.46|
# |Def Loss 0.2387 | Def Reward in ep 095|
# |Att Loss 0.1098 | Att Reward in ep 005|
# |Def Estimated: [ 9 16 22 53]| Att Labels: [ 8 15 24 53]
#
# |Epoch 027/500| time: 48.66|
# |Def Loss 0.2338 | Def Reward in ep 095|
# |Att Loss 0.1083 | Att Reward in ep 005|
# |Def Estimated: [ 6 21 24 49]| Att Labels: [ 6 17 25 52]
#
# |Epoch 028/500| time: 47.46|
# |Def Loss 0.2290 | Def Reward in ep 095|
# |Att Loss 0.1069 | Att Reward in ep 005|
# |Def Estimated: [ 9  9 40 42]| Att Labels: [ 8 10 40 42]
#
# |Epoch 029/500| time: 49.16|
# |Def Loss 0.2250 | Def Reward in ep 095|
# |Att Loss 0.1057 | Att Reward in ep 005|
# |Def Estimated: [ 8 11 25 56]| Att Labels: [ 7 11 26 56]
#
# |Epoch 030/500| time: 47.99|
# |Def Loss 0.2208 | Def Reward in ep 091|
# |Att Loss 0.1044 | Att Reward in ep 009|
# |Def Estimated: [ 8 22 31 39]| Att Labels: [ 9 21 34 36]
#
# |Epoch 031/500| time: 47.44|
# |Def Loss 0.2171 | Def Reward in ep 096|
# |Att Loss 0.1029 | Att Reward in ep 004|
# |Def Estimated: [ 8 18 29 45]| Att Labels: [ 9 18 27 46]
#
# |Epoch 032/500| time: 46.29|
# |Def Loss 0.2130 | Def Reward in ep 096|
# |Att Loss 0.1012 | Att Reward in ep 004|
# |Def Estimated: [ 9 17 27 47]| Att Labels: [ 8 15 26 51]
#
# |Epoch 033/500| time: 48.94|
# |Def Loss 0.2091 | Def Reward in ep 096|
# |Att Loss 0.0995 | Att Reward in ep 004|
# |Def Estimated: [15 13 25 47]| Att Labels: [14 11 25 50]
#
# |Epoch 034/500| time: 47.36|
# |Def Loss 0.2058 | Def Reward in ep 088|
# |Att Loss 0.0979 | Att Reward in ep 012|
# |Def Estimated: [11 18 25 46]| Att Labels: [ 9 15 31 45]
#
# |Epoch 035/500| time: 47.17|
# |Def Loss 0.2028 | Def Reward in ep 096|
# |Att Loss 0.0963 | Att Reward in ep 004|
# |Def Estimated: [12 17 28 43]| Att Labels: [11 17 27 45]
#
# |Epoch 036/500| time: 48.84|
# |Def Loss 0.2000 | Def Reward in ep 095|
# |Att Loss 0.0948 | Att Reward in ep 005|
# |Def Estimated: [ 9 11 23 57]| Att Labels: [ 9 11 20 60]
#
# |Epoch 037/500| time: 49.42|
# |Def Loss 0.1967 | Def Reward in ep 085|
# |Att Loss 0.0933 | Att Reward in ep 015|
# |Def Estimated: [12 14 33 41]| Att Labels: [12 12 33 43]
#
# |Epoch 038/500| time: 48.44|
# |Def Loss 0.1937 | Def Reward in ep 096|
# |Att Loss 0.0919 | Att Reward in ep 004|
# |Def Estimated: [10 11 25 54]| Att Labels: [ 7 11 26 56]
#
# |Epoch 039/500| time: 48.02|
# |Def Loss 0.1910 | Def Reward in ep 092|
# |Att Loss 0.0905 | Att Reward in ep 008|
# |Def Estimated: [ 8 18 27 47]| Att Labels: [ 9 17 30 44]
#
# |Epoch 040/500| time: 49.58|
# |Def Loss 0.1880 | Def Reward in ep 094|
# |Att Loss 0.0892 | Att Reward in ep 006|
# |Def Estimated: [ 6 17 27 50]| Att Labels: [ 5 16 27 52]
#
# |Epoch 041/500| time: 49.09|
# |Def Loss 0.1854 | Def Reward in ep 096|
# |Att Loss 0.0880 | Att Reward in ep 004|
# |Def Estimated: [10 15 19 56]| Att Labels: [10 13 21 56]
#
# |Epoch 042/500| time: 47.18|
# |Def Loss 0.1835 | Def Reward in ep 095|
# |Att Loss 0.0868 | Att Reward in ep 005|
# |Def Estimated: [ 8 25 28 39]| Att Labels: [ 7 23 29 41]
#
# |Epoch 043/500| time: 49.42|
# |Def Loss 0.1811 | Def Reward in ep 094|
# |Att Loss 0.0856 | Att Reward in ep 006|
# |Def Estimated: [ 5 13 28 54]| Att Labels: [ 5 15 26 54]
#
# |Epoch 044/500| time: 49.89|
# |Def Loss 0.1785 | Def Reward in ep 095|
# |Att Loss 0.0845 | Att Reward in ep 005|
# |Def Estimated: [12 22 23 43]| Att Labels: [12 20 23 45]
#
# |Epoch 045/500| time: 48.41|
# |Def Loss 0.1761 | Def Reward in ep 096|
# |Att Loss 0.0834 | Att Reward in ep 004|
# |Def Estimated: [11 13 28 48]| Att Labels: [10 12 29 49]
#
# |Epoch 046/500| time: 47.37|
# |Def Loss 0.1735 | Def Reward in ep 093|
# |Att Loss 0.0823 | Att Reward in ep 007|
# |Def Estimated: [ 4 21 23 52]| Att Labels: [ 1 18 25 56]
#
# |Epoch 047/500| time: 50.01|
# |Def Loss 0.1710 | Def Reward in ep 095|
# |Att Loss 0.0814 | Att Reward in ep 005|
# |Def Estimated: [ 9 13 24 54]| Att Labels: [ 8 13 21 58]
#
# |Epoch 048/500| time: 51.47|
# |Def Loss 0.1685 | Def Reward in ep 097|
# |Att Loss 0.0804 | Att Reward in ep 003|
# |Def Estimated: [ 7 15 22 56]| Att Labels: [ 7 14 21 58]
#
# |Epoch 049/500| time: 46.16|
# |Def Loss 0.1661 | Def Reward in ep 097|
# |Att Loss 0.0795 | Att Reward in ep 003|
# |Def Estimated: [ 8 11 35 46]| Att Labels: [ 7 11 35 47]
#
# |Epoch 050/500| time: 49.11|
# |Def Loss 0.1637 | Def Reward in ep 093|
# |Att Loss 0.0786 | Att Reward in ep 007|
# |Def Estimated: [10 15 26 49]| Att Labels: [10 12 24 54]
#
# |Epoch 051/500| time: 48.76|
# |Def Loss 0.1617 | Def Reward in ep 097|
# |Att Loss 0.0778 | Att Reward in ep 003|
# |Def Estimated: [11 17 26 46]| Att Labels: [10 16 25 49]
#
# |Epoch 052/500| time: 46.65|
# |Def Loss 0.1599 | Def Reward in ep 094|
# |Att Loss 0.0769 | Att Reward in ep 006|
# |Def Estimated: [ 9 18 23 50]| Att Labels: [ 9 16 23 52]
#
# |Epoch 053/500| time: 46.96|
# |Def Loss 0.1580 | Def Reward in ep 097|
# |Att Loss 0.0761 | Att Reward in ep 003|
# |Def Estimated: [12 17 20 51]| Att Labels: [10 16 21 53]
#
# |Epoch 054/500| time: 49.70|
# |Def Loss 0.1559 | Def Reward in ep 092|
# |Att Loss 0.0753 | Att Reward in ep 008|
# |Def Estimated: [15 19 28 38]| Att Labels: [12 18 29 41]
#
# |Epoch 055/500| time: 48.17|
# |Def Loss 0.1538 | Def Reward in ep 095|
# |Att Loss 0.0746 | Att Reward in ep 005|
# |Def Estimated: [ 4 13 33 50]| Att Labels: [ 4 13 34 49]
#
# |Epoch 056/500| time: 45.98|
# |Def Loss 0.1517 | Def Reward in ep 094|
# |Att Loss 0.0738 | Att Reward in ep 006|
# |Def Estimated: [ 7 17 28 48]| Att Labels: [ 6 17 30 47]
#
# |Epoch 057/500| time: 49.91|
# |Def Loss 0.1498 | Def Reward in ep 095|
# |Att Loss 0.0731 | Att Reward in ep 005|
# |Def Estimated: [ 9  8 30 53]| Att Labels: [10  7 29 54]
#
# |Epoch 058/500| time: 49.86|
# |Def Loss 0.1481 | Def Reward in ep 098|
# |Att Loss 0.0725 | Att Reward in ep 002|
# |Def Estimated: [ 8 19 26 47]| Att Labels: [ 7 19 27 47]
#
# |Epoch 059/500| time: 46.78|
# |Def Loss 0.1465 | Def Reward in ep 094|
# |Att Loss 0.0718 | Att Reward in ep 006|
# |Def Estimated: [ 6 16 32 46]| Att Labels: [ 5 15 32 48]
#
# |Epoch 060/500| time: 48.29|
# |Def Loss 0.1446 | Def Reward in ep 092|
# |Att Loss 0.0711 | Att Reward in ep 008|
# |Def Estimated: [ 9 16 25 50]| Att Labels: [ 9 16 25 50]
#
# |Epoch 061/500| time: 50.21|
# |Def Loss 0.1430 | Def Reward in ep 099|
# |Att Loss 0.0705 | Att Reward in ep 001|
# |Def Estimated: [ 8 15 25 52]| Att Labels: [ 8 15 24 53]
#
# |Epoch 062/500| time: 47.69|
# |Def Loss 0.1416 | Def Reward in ep 096|
# |Att Loss 0.0699 | Att Reward in ep 004|
# |Def Estimated: [ 7 16 32 45]| Att Labels: [ 7 14 31 48]
#
# |Epoch 063/500| time: 47.27|
# |Def Loss 0.1401 | Def Reward in ep 096|
# |Att Loss 0.0693 | Att Reward in ep 004|
# |Def Estimated: [ 7 14 21 58]| Att Labels: [ 6 12 24 58]
#
# |Epoch 064/500| time: 48.66|
# |Def Loss 0.1386 | Def Reward in ep 098|
# |Att Loss 0.0687 | Att Reward in ep 002|
# |Def Estimated: [ 8 21 28 43]| Att Labels: [ 8 20 29 43]
#
# |Epoch 065/500| time: 48.05|
# |Def Loss 0.1372 | Def Reward in ep 092|
# |Att Loss 0.0681 | Att Reward in ep 008|
# |Def Estimated: [ 9 16 24 51]| Att Labels: [ 8 13 25 54]
#
# |Epoch 066/500| time: 47.26|
# |Def Loss 0.1360 | Def Reward in ep 096|
# |Att Loss 0.0675 | Att Reward in ep 004|
# |Def Estimated: [ 7 16 21 56]| Att Labels: [ 8 15 21 56]
#
# |Epoch 067/500| time: 48.95|
# |Def Loss 0.1347 | Def Reward in ep 099|
# |Att Loss 0.0670 | Att Reward in ep 001|
# |Def Estimated: [11 10 33 46]| Att Labels: [11 10 32 47]
#
# |Epoch 068/500| time: 48.78|
# |Def Loss 0.1332 | Def Reward in ep 096|
# |Att Loss 0.0664 | Att Reward in ep 004|
# |Def Estimated: [ 6 19 28 47]| Att Labels: [ 7 17 29 47]
#
# |Epoch 069/500| time: 46.61|
# |Def Loss 0.1316 | Def Reward in ep 093|
# |Att Loss 0.0658 | Att Reward in ep 007|
# |Def Estimated: [ 7 20 29 44]| Att Labels: [ 8 19 28 45]
#
# |Epoch 070/500| time: 45.89|
# |Def Loss 0.1301 | Def Reward in ep 094|
# |Att Loss 0.0653 | Att Reward in ep 006|
# |Def Estimated: [ 6 20 23 51]| Att Labels: [ 6 20 24 50]
#
# |Epoch 071/500| time: 49.46|
# |Def Loss 0.1288 | Def Reward in ep 097|
# |Att Loss 0.0648 | Att Reward in ep 003|
# |Def Estimated: [ 7 11 33 49]| Att Labels: [ 7 10 31 52]
#
# |Epoch 072/500| time: 47.55|
# |Def Loss 0.1276 | Def Reward in ep 090|
# |Att Loss 0.0643 | Att Reward in ep 010|
# |Def Estimated: [10 22 28 40]| Att Labels: [12 17 31 40]
#
# |Epoch 073/500| time: 46.68|
# |Def Loss 0.1264 | Def Reward in ep 095|
# |Att Loss 0.0639 | Att Reward in ep 005|
# |Def Estimated: [ 9 14 30 47]| Att Labels: [ 9 13 29 49]
#
# |Epoch 074/500| time: 47.60|
# |Def Loss 0.1253 | Def Reward in ep 097|
# |Att Loss 0.0634 | Att Reward in ep 003|
# |Def Estimated: [ 8 19 25 48]| Att Labels: [ 9 18 23 50]
#
# |Epoch 075/500| time: 49.51|
# |Def Loss 0.1242 | Def Reward in ep 094|
# |Att Loss 0.0629 | Att Reward in ep 006|
# |Def Estimated: [ 7 23 23 47]| Att Labels: [ 9 20 25 46]
#
# |Epoch 076/500| time: 45.86|
# |Def Loss 0.1231 | Def Reward in ep 096|
# |Att Loss 0.0625 | Att Reward in ep 004|
# |Def Estimated: [13 21 24 42]| Att Labels: [12 20 25 43]
#
# |Epoch 077/500| time: 46.33|
# |Def Loss 0.1219 | Def Reward in ep 094|
# |Att Loss 0.0621 | Att Reward in ep 006|
# |Def Estimated: [ 7 17 22 54]| Att Labels: [ 4 16 22 58]
#
# |Epoch 078/500| time: 48.85|
# |Def Loss 0.1209 | Def Reward in ep 095|
# |Att Loss 0.0616 | Att Reward in ep 005|
# |Def Estimated: [ 7 21 24 48]| Att Labels: [ 7 21 20 52]
#
# |Epoch 079/500| time: 48.04|
# |Def Loss 0.1200 | Def Reward in ep 098|
# |Att Loss 0.0612 | Att Reward in ep 002|
# |Def Estimated: [13 23 26 38]| Att Labels: [12 24 26 38]
#
# |Epoch 080/500| time: 46.73|
# |Def Loss 0.1190 | Def Reward in ep 093|
# |Att Loss 0.0608 | Att Reward in ep 007|
# |Def Estimated: [15 16 21 48]| Att Labels: [12 16 25 47]
#
# |Epoch 081/500| time: 47.44|
# |Def Loss 0.1181 | Def Reward in ep 097|
# |Att Loss 0.0604 | Att Reward in ep 003|
# |Def Estimated: [13 21 25 41]| Att Labels: [12 21 26 41]
#
# |Epoch 082/500| time: 49.05|
# |Def Loss 0.1172 | Def Reward in ep 094|
# |Att Loss 0.0600 | Att Reward in ep 006|
# |Def Estimated: [11 21 25 43]| Att Labels: [13 20 24 43]
#
# |Epoch 083/500| time: 46.97|
# |Def Loss 0.1165 | Def Reward in ep 093|
# |Att Loss 0.0597 | Att Reward in ep 007|
# |Def Estimated: [15 16 29 40]| Att Labels: [14 17 26 43]
#
# |Epoch 084/500| time: 45.73|
# |Def Loss 0.1156 | Def Reward in ep 091|
# |Att Loss 0.0593 | Att Reward in ep 009|
# |Def Estimated: [14 10 33 43]| Att Labels: [12 10 33 45]
#
# |Epoch 085/500| time: 48.46|
# |Def Loss 0.1148 | Def Reward in ep 095|
# |Att Loss 0.0590 | Att Reward in ep 005|
# |Def Estimated: [13 14 26 47]| Att Labels: [12 12 27 49]
#
# |Epoch 086/500| time: 47.50|
# |Def Loss 0.1141 | Def Reward in ep 098|
# |Att Loss 0.0586 | Att Reward in ep 002|
# |Def Estimated: [ 9 15 24 52]| Att Labels: [ 8 16 25 51]
#
# |Epoch 087/500| time: 47.10|
# |Def Loss 0.1132 | Def Reward in ep 096|
# |Att Loss 0.0583 | Att Reward in ep 004|
# |Def Estimated: [11 20 24 45]| Att Labels: [12 19 23 46]
#
# |Epoch 088/500| time: 47.24|
# |Def Loss 0.1123 | Def Reward in ep 092|
# |Att Loss 0.0580 | Att Reward in ep 008|
# |Def Estimated: [ 8 21 33 38]| Att Labels: [ 8 20 34 38]
#
# |Epoch 089/500| time: 48.56|
# |Def Loss 0.1115 | Def Reward in ep 093|
# |Att Loss 0.0577 | Att Reward in ep 007|
# |Def Estimated: [ 9 24 21 46]| Att Labels: [ 8 20 20 52]
#
# |Epoch 090/500| time: 47.26|
# |Def Loss 0.1106 | Def Reward in ep 096|
# |Att Loss 0.0574 | Att Reward in ep 004|
# |Def Estimated: [ 7 16 32 45]| Att Labels: [ 7 17 32 44]
#
# |Epoch 091/500| time: 46.68|
# |Def Loss 0.1097 | Def Reward in ep 096|
# |Att Loss 0.0571 | Att Reward in ep 004|
# |Def Estimated: [ 5 18 20 57]| Att Labels: [ 4 18 20 58]
#
# |Epoch 092/500| time: 48.97|
# |Def Loss 0.1090 | Def Reward in ep 092|
# |Att Loss 0.0568 | Att Reward in ep 008|
# |Def Estimated: [ 7 21 24 48]| Att Labels: [ 9 19 28 44]
#
# |Epoch 093/500| time: 48.25|
# |Def Loss 0.1082 | Def Reward in ep 096|
# |Att Loss 0.0565 | Att Reward in ep 004|
# |Def Estimated: [14 17 28 41]| Att Labels: [13 19 27 41]
#
# |Epoch 094/500| time: 46.20|
# |Def Loss 0.1075 | Def Reward in ep 095|
# |Att Loss 0.0562 | Att Reward in ep 005|
# |Def Estimated: [13 11 30 46]| Att Labels: [11 11 29 49]
#
# |Epoch 095/500| time: 47.58|
# |Def Loss 0.1067 | Def Reward in ep 094|
# |Att Loss 0.0560 | Att Reward in ep 006|
# |Def Estimated: [ 9 13 35 43]| Att Labels: [10 12 33 45]
#
# |Epoch 096/500| time: 48.74|
# |Def Loss 0.1058 | Def Reward in ep 096|
# |Att Loss 0.0557 | Att Reward in ep 004|
# |Def Estimated: [ 7 21 30 42]| Att Labels: [ 8 20 31 41]
#
# |Epoch 097/500| time: 45.40|
# |Def Loss 0.1050 | Def Reward in ep 094|
# |Att Loss 0.0554 | Att Reward in ep 006|
# |Def Estimated: [13 16 26 45]| Att Labels: [12 15 27 46]
#
# |Epoch 098/500| time: 46.88|
# |Def Loss 0.1043 | Def Reward in ep 093|
# |Att Loss 0.0552 | Att Reward in ep 007|
# |Def Estimated: [13 13 26 48]| Att Labels: [12 13 24 51]
#
# |Epoch 099/500| time: 48.96|
# |Def Loss 0.1036 | Def Reward in ep 093|
# |Att Loss 0.0550 | Att Reward in ep 007|
# |Def Estimated: [14 16 30 40]| Att Labels: [13 15 28 44]
#
# |Epoch 100/500| time: 48.28|
# |Def Loss 0.1029 | Def Reward in ep 096|
# |Att Loss 0.0547 | Att Reward in ep 004|
# |Def Estimated: [11 15 28 46]| Att Labels: [12 14 27 47]
#
# |Epoch 101/500| time: 46.17|
# |Def Loss 0.1021 | Def Reward in ep 094|
# |Att Loss 0.0545 | Att Reward in ep 006|
# |Def Estimated: [ 8 16 30 46]| Att Labels: [ 7 18 28 47]
#
# |Epoch 102/500| time: 47.56|
# |Def Loss 0.1013 | Def Reward in ep 095|
# |Att Loss 0.0543 | Att Reward in ep 005|
# |Def Estimated: [10 14 27 49]| Att Labels: [11 14 27 48]
#
# |Epoch 103/500| time: 46.99|
# |Def Loss 0.1006 | Def Reward in ep 095|
# |Att Loss 0.0541 | Att Reward in ep 005|
# |Def Estimated: [12 15 23 50]| Att Labels: [13 14 24 49]
#
# |Epoch 104/500| time: 46.35|
# |Def Loss 0.1001 | Def Reward in ep 097|
# |Att Loss 0.0539 | Att Reward in ep 003|
# |Def Estimated: [10 20 25 45]| Att Labels: [11 20 24 45]
#
# |Epoch 105/500| time: 46.76|
# |Def Loss 0.0994 | Def Reward in ep 096|
# |Att Loss 0.0536 | Att Reward in ep 004|
# |Def Estimated: [12 16 22 50]| Att Labels: [11 16 23 50]
#
# |Epoch 106/500| time: 48.68|
# |Def Loss 0.0988 | Def Reward in ep 095|
# |Att Loss 0.0534 | Att Reward in ep 005|
# |Def Estimated: [14 12 32 42]| Att Labels: [13 12 33 42]
#
# |Epoch 107/500| time: 46.05|
# |Def Loss 0.0983 | Def Reward in ep 094|
# |Att Loss 0.0532 | Att Reward in ep 006|
# |Def Estimated: [ 5 17 30 48]| Att Labels: [ 6 16 31 47]
#
# |Epoch 108/500| time: 45.65|
# |Def Loss 0.0978 | Def Reward in ep 096|
# |Att Loss 0.0530 | Att Reward in ep 004|
# |Def Estimated: [11 19 24 46]| Att Labels: [11 19 26 44]
#
# |Epoch 109/500| time: 47.05|
# |Def Loss 0.0973 | Def Reward in ep 098|
# |Att Loss 0.0528 | Att Reward in ep 002|
# |Def Estimated: [ 7 12 27 54]| Att Labels: [ 6 12 26 56]
#
# |Epoch 110/500| time: 46.99|
# |Def Loss 0.0969 | Def Reward in ep 095|
# |Att Loss 0.0526 | Att Reward in ep 005|
# |Def Estimated: [11 14 22 53]| Att Labels: [12 14 20 54]
#
# |Epoch 111/500| time: 46.79|
# |Def Loss 0.0963 | Def Reward in ep 096|
# |Att Loss 0.0524 | Att Reward in ep 004|
# |Def Estimated: [12 14 30 44]| Att Labels: [12 14 31 43]
#
# |Epoch 112/500| time: 46.09|
# |Def Loss 0.0958 | Def Reward in ep 093|
# |Att Loss 0.0522 | Att Reward in ep 007|
# |Def Estimated: [14 11 34 41]| Att Labels: [14 10 33 43]
#
# |Epoch 113/500| time: 49.76|
# |Def Loss 0.0954 | Def Reward in ep 097|
# |Att Loss 0.0520 | Att Reward in ep 003|
# |Def Estimated: [13 12 31 44]| Att Labels: [13 12 32 43]
#
# |Epoch 114/500| time: 46.28|
# |Def Loss 0.0950 | Def Reward in ep 095|
# |Att Loss 0.0517 | Att Reward in ep 005|
# |Def Estimated: [ 9 15 30 46]| Att Labels: [ 8 13 32 47]
#
# |Epoch 115/500| time: 46.20|
# |Def Loss 0.0945 | Def Reward in ep 093|
# |Att Loss 0.0515 | Att Reward in ep 007|
# |Def Estimated: [14 14 23 49]| Att Labels: [14 14 26 46]
#
# |Epoch 116/500| time: 47.80|
# |Def Loss 0.0939 | Def Reward in ep 093|
# |Att Loss 0.0513 | Att Reward in ep 007|
# |Def Estimated: [ 9 17 27 47]| Att Labels: [10 16 24 50]
#
# |Epoch 117/500| time: 48.13|
# |Def Loss 0.0934 | Def Reward in ep 097|
# |Att Loss 0.0511 | Att Reward in ep 003|
# |Def Estimated: [14 16 30 40]| Att Labels: [14 15 31 40]
#
# |Epoch 118/500| time: 46.46|
# |Def Loss 0.0929 | Def Reward in ep 096|
# |Att Loss 0.0510 | Att Reward in ep 004|
# |Def Estimated: [ 8 15 35 42]| Att Labels: [10 14 33 43]
#
# |Epoch 119/500| time: 45.15|
# |Def Loss 0.0923 | Def Reward in ep 096|
# |Att Loss 0.0508 | Att Reward in ep 004|
# |Def Estimated: [16 16 28 40]| Att Labels: [17 16 28 39]
#
# |Epoch 120/500| time: 47.89|
# |Def Loss 0.0918 | Def Reward in ep 094|
# |Att Loss 0.0506 | Att Reward in ep 006|
# |Def Estimated: [10 11 28 51]| Att Labels: [ 7 10 28 55]
#
# |Epoch 121/500| time: 47.01|
# |Def Loss 0.0913 | Def Reward in ep 096|
# |Att Loss 0.0504 | Att Reward in ep 004|
# |Def Estimated: [12 25 25 38]| Att Labels: [11 25 24 40]
#
# |Epoch 122/500| time: 47.51|
# |Def Loss 0.0908 | Def Reward in ep 097|
# |Att Loss 0.0502 | Att Reward in ep 003|
# |Def Estimated: [14 13 25 48]| Att Labels: [12 12 27 49]
#
# |Epoch 123/500| time: 48.23|
# |Def Loss 0.0903 | Def Reward in ep 096|
# |Att Loss 0.0500 | Att Reward in ep 004|
# |Def Estimated: [17 20 22 41]| Att Labels: [17 18 25 40]
#
# |Epoch 124/500| time: 47.45|
# |Def Loss 0.0897 | Def Reward in ep 094|
# |Att Loss 0.0498 | Att Reward in ep 006|
# |Def Estimated: [13 19 20 48]| Att Labels: [13 17 19 51]
#
# |Epoch 125/500| time: 45.75|
# |Def Loss 0.0893 | Def Reward in ep 097|
# |Att Loss 0.0496 | Att Reward in ep 003|
# |Def Estimated: [13 15 19 53]| Att Labels: [13 13 20 54]
#
# |Epoch 126/500| time: 46.03|
# |Def Loss 0.0888 | Def Reward in ep 094|
# |Att Loss 0.0494 | Att Reward in ep 006|
# |Def Estimated: [ 9 13 28 50]| Att Labels: [ 8 12 28 52]
#
# |Epoch 127/500| time: 49.12|
# |Def Loss 0.0883 | Def Reward in ep 096|
# |Att Loss 0.0492 | Att Reward in ep 004|
# |Def Estimated: [ 6 17 25 52]| Att Labels: [ 7 15 26 52]
#
# |Epoch 128/500| time: 47.66|
# |Def Loss 0.0879 | Def Reward in ep 097|
# |Att Loss 0.0490 | Att Reward in ep 003|
# |Def Estimated: [12 20 21 47]| Att Labels: [12 19 20 49]
#
# |Epoch 129/500| time: 47.33|
# |Def Loss 0.0874 | Def Reward in ep 097|
# |Att Loss 0.0488 | Att Reward in ep 003|
# |Def Estimated: [15 18 23 44]| Att Labels: [15 17 23 45]
#
# |Epoch 130/500| time: 48.70|
# |Def Loss 0.0869 | Def Reward in ep 097|
# |Att Loss 0.0487 | Att Reward in ep 003|
# |Def Estimated: [ 7 18 26 49]| Att Labels: [ 9 18 26 47]
#
# |Epoch 131/500| time: 48.87|
# |Def Loss 0.0865 | Def Reward in ep 097|
# |Att Loss 0.0485 | Att Reward in ep 003|
# |Def Estimated: [ 8 13 30 49]| Att Labels: [ 8 12 31 49]
#
# |Epoch 132/500| time: 47.05|
# |Def Loss 0.0861 | Def Reward in ep 092|
# |Att Loss 0.0483 | Att Reward in ep 008|
# |Def Estimated: [11 17 17 55]| Att Labels: [11 16 16 57]
#
# |Epoch 133/500| time: 45.80|
# |Def Loss 0.0858 | Def Reward in ep 098|
# |Att Loss 0.0481 | Att Reward in ep 002|
# |Def Estimated: [11 15 23 51]| Att Labels: [ 9 15 23 53]
#
# |Epoch 134/500| time: 49.00|
# |Def Loss 0.0854 | Def Reward in ep 095|
# |Att Loss 0.0479 | Att Reward in ep 005|
# |Def Estimated: [18 20 26 36]| Att Labels: [17 20 27 36]
#
# |Epoch 135/500| time: 46.86|
# |Def Loss 0.0850 | Def Reward in ep 100|
# |Att Loss 0.0477 | Att Reward in ep 000|
# |Def Estimated: [ 7 13 24 56]| Att Labels: [ 7 13 24 56]
#
# |Epoch 136/500| time: 46.03|
# |Def Loss 0.0845 | Def Reward in ep 095|
# |Att Loss 0.0476 | Att Reward in ep 005|
# |Def Estimated: [12 17 29 42]| Att Labels: [14 17 27 42]
#
# |Epoch 137/500| time: 47.89|
# |Def Loss 0.0841 | Def Reward in ep 095|
# |Att Loss 0.0474 | Att Reward in ep 005|
# |Def Estimated: [ 9 13 24 54]| Att Labels: [ 9 14 23 54]
#
# |Epoch 138/500| time: 47.43|
# |Def Loss 0.0837 | Def Reward in ep 097|
# |Att Loss 0.0472 | Att Reward in ep 003|
# |Def Estimated: [12 18 28 42]| Att Labels: [13 18 28 41]
#
# |Epoch 139/500| time: 45.68|
# |Def Loss 0.0833 | Def Reward in ep 097|
# |Att Loss 0.0471 | Att Reward in ep 003|
# |Def Estimated: [14 15 19 52]| Att Labels: [13 13 20 54]
#
# |Epoch 140/500| time: 45.73|
# |Def Loss 0.0829 | Def Reward in ep 095|
# |Att Loss 0.0469 | Att Reward in ep 005|
# |Def Estimated: [15 12 31 42]| Att Labels: [13 13 33 41]
#
# |Epoch 141/500| time: 49.11|
# |Def Loss 0.0826 | Def Reward in ep 097|
# |Att Loss 0.0467 | Att Reward in ep 003|
# |Def Estimated: [15 19 22 44]| Att Labels: [15 19 23 43]
#
# |Epoch 142/500| time: 45.19|
# |Def Loss 0.0823 | Def Reward in ep 093|
# |Att Loss 0.0466 | Att Reward in ep 007|
# |Def Estimated: [12 17 25 46]| Att Labels: [10 15 27 48]
#
# |Epoch 143/500| time: 46.48|
# |Def Loss 0.0820 | Def Reward in ep 095|
# |Att Loss 0.0464 | Att Reward in ep 005|
# |Def Estimated: [15 14 20 51]| Att Labels: [16 11 21 52]
#
# |Epoch 144/500| time: 49.50|
# |Def Loss 0.0816 | Def Reward in ep 097|
# |Att Loss 0.0463 | Att Reward in ep 003|
# |Def Estimated: [11 18 26 45]| Att Labels: [11 19 25 45]
#
# |Epoch 145/500| time: 47.95|
# |Def Loss 0.0813 | Def Reward in ep 097|
# |Att Loss 0.0461 | Att Reward in ep 003|
# |Def Estimated: [14 16 19 51]| Att Labels: [12 15 20 53]
#
# |Epoch 146/500| time: 46.22|
# |Def Loss 0.0809 | Def Reward in ep 098|
# |Att Loss 0.0460 | Att Reward in ep 002|
# |Def Estimated: [14 21 23 42]| Att Labels: [14 21 23 42]
#
# |Epoch 147/500| time: 45.33|
# |Def Loss 0.0806 | Def Reward in ep 097|
# |Att Loss 0.0458 | Att Reward in ep 003|
# |Def Estimated: [ 8  8 25 59]| Att Labels: [ 9  8 25 58]
#
# |Epoch 148/500| time: 47.40|
# |Def Loss 0.0803 | Def Reward in ep 094|
# |Att Loss 0.0457 | Att Reward in ep 006|
# |Def Estimated: [ 8 17 30 45]| Att Labels: [ 7 16 29 48]
#
# |Epoch 149/500| time: 46.86|
# |Def Loss 0.0799 | Def Reward in ep 093|
# |Att Loss 0.0455 | Att Reward in ep 007|
# |Def Estimated: [12 13 27 48]| Att Labels: [12 15 24 49]
#
# |Epoch 150/500| time: 46.91|
# |Def Loss 0.0796 | Def Reward in ep 096|
# |Att Loss 0.0454 | Att Reward in ep 004|
# |Def Estimated: [13 11 31 45]| Att Labels: [12 12 33 43]
#
# |Epoch 151/500| time: 47.64|
# |Def Loss 0.0794 | Def Reward in ep 096|
# |Att Loss 0.0452 | Att Reward in ep 004|
# |Def Estimated: [ 8 13 30 49]| Att Labels: [ 8 11 31 50]
#
# |Epoch 152/500| time: 47.40|
# |Def Loss 0.0791 | Def Reward in ep 098|
# |Att Loss 0.0451 | Att Reward in ep 002|
# |Def Estimated: [13 18 22 47]| Att Labels: [13 17 22 48]
#
# |Epoch 153/500| time: 45.03|
# |Def Loss 0.0789 | Def Reward in ep 097|
# |Att Loss 0.0449 | Att Reward in ep 003|
# |Def Estimated: [ 6 14 18 62]| Att Labels: [ 5 14 21 60]
#
# |Epoch 154/500| time: 46.98|
# |Def Loss 0.0786 | Def Reward in ep 097|
# |Att Loss 0.0448 | Att Reward in ep 003|
# |Def Estimated: [15 22 20 43]| Att Labels: [14 22 21 43]
#
# |Epoch 155/500| time: 48.79|
# |Def Loss 0.0783 | Def Reward in ep 092|
# |Att Loss 0.0446 | Att Reward in ep 008|
# |Def Estimated: [14 19 21 46]| Att Labels: [14 18 25 43]
#
# |Epoch 156/500| time: 46.91|
# |Def Loss 0.0781 | Def Reward in ep 093|
# |Att Loss 0.0445 | Att Reward in ep 007|
# |Def Estimated: [12 21 29 38]| Att Labels: [11 19 30 40]
#
# |Epoch 157/500| time: 45.71|
# |Def Loss 0.0780 | Def Reward in ep 096|
# |Att Loss 0.0444 | Att Reward in ep 004|
# |Def Estimated: [10 23 21 46]| Att Labels: [10 22 20 48]
#
# |Epoch 158/500| time: 47.91|
# |Def Loss 0.0777 | Def Reward in ep 095|
# |Att Loss 0.0442 | Att Reward in ep 005|
# |Def Estimated: [16 19 21 44]| Att Labels: [15 19 24 42]
#
# |Epoch 159/500| time: 48.71|
# |Def Loss 0.0775 | Def Reward in ep 094|
# |Att Loss 0.0441 | Att Reward in ep 006|
# |Def Estimated: [ 9 22 27 42]| Att Labels: [11 19 27 43]
#
# |Epoch 160/500| time: 48.37|
# |Def Loss 0.0773 | Def Reward in ep 096|
# |Att Loss 0.0440 | Att Reward in ep 004|
# |Def Estimated: [12 12 27 49]| Att Labels: [11 12 26 51]
#
# |Epoch 161/500| time: 47.33|
# |Def Loss 0.0771 | Def Reward in ep 094|
# |Att Loss 0.0439 | Att Reward in ep 006|
# |Def Estimated: [11 18 27 44]| Att Labels: [ 9 18 27 46]
#
# |Epoch 162/500| time: 49.33|
# |Def Loss 0.0770 | Def Reward in ep 094|
# |Att Loss 0.0437 | Att Reward in ep 006|
# |Def Estimated: [12 17 28 43]| Att Labels: [ 9 18 28 45]
#
# |Epoch 163/500| time: 48.93|
# |Def Loss 0.0767 | Def Reward in ep 098|
# |Att Loss 0.0436 | Att Reward in ep 002|
# |Def Estimated: [ 6 20 26 48]| Att Labels: [ 6 20 26 48]
#
# |Epoch 164/500| time: 46.22|
# |Def Loss 0.0765 | Def Reward in ep 095|
# |Att Loss 0.0435 | Att Reward in ep 005|
# |Def Estimated: [10 16 21 53]| Att Labels: [ 8 15 21 56]
#
# |Epoch 165/500| time: 48.45|
# |Def Loss 0.0763 | Def Reward in ep 098|
# |Att Loss 0.0434 | Att Reward in ep 002|
# |Def Estimated: [ 9 17 26 48]| Att Labels: [ 8 17 25 50]
#
# |Epoch 166/500| time: 48.02|
# |Def Loss 0.0761 | Def Reward in ep 094|
# |Att Loss 0.0433 | Att Reward in ep 006|
# |Def Estimated: [16 18 20 46]| Att Labels: [14 18 24 44]
#
# |Epoch 167/500| time: 46.23|
# |Def Loss 0.0758 | Def Reward in ep 095|
# |Att Loss 0.0432 | Att Reward in ep 005|
# |Def Estimated: [ 9 19 26 46]| Att Labels: [10 18 26 46]
#
# |Epoch 168/500| time: 46.12|
# |Def Loss 0.0756 | Def Reward in ep 092|
# |Att Loss 0.0430 | Att Reward in ep 008|
# |Def Estimated: [12 19 32 37]| Att Labels: [10 21 29 40]
#
# |Epoch 169/500| time: 49.42|
# |Def Loss 0.0755 | Def Reward in ep 096|
# |Att Loss 0.0429 | Att Reward in ep 004|
# |Def Estimated: [13 16 34 37]| Att Labels: [13 14 33 40]
#
# |Epoch 170/500| time: 48.15|
# |Def Loss 0.0752 | Def Reward in ep 098|
# |Att Loss 0.0428 | Att Reward in ep 002|
# |Def Estimated: [ 9 20 26 45]| Att Labels: [ 8 20 27 45]
#
# |Epoch 171/500| time: 47.04|
# |Def Loss 0.0749 | Def Reward in ep 096|
# |Att Loss 0.0427 | Att Reward in ep 004|
# |Def Estimated: [ 9 22 28 41]| Att Labels: [11 20 28 41]
#
# |Epoch 172/500| time: 49.42|
# |Def Loss 0.0746 | Def Reward in ep 095|
# |Att Loss 0.0426 | Att Reward in ep 005|
# |Def Estimated: [ 7 17 18 58]| Att Labels: [ 6 17 17 60]
#
# |Epoch 173/500| time: 48.20|
# |Def Loss 0.0743 | Def Reward in ep 096|
# |Att Loss 0.0425 | Att Reward in ep 004|
# |Def Estimated: [11 17 28 44]| Att Labels: [ 9 16 27 48]
#
# |Epoch 174/500| time: 46.69|
# |Def Loss 0.0740 | Def Reward in ep 098|
# |Att Loss 0.0424 | Att Reward in ep 002|
# |Def Estimated: [ 9 15 25 51]| Att Labels: [ 9 16 23 52]
#
# |Epoch 175/500| time: 46.73|
# |Def Loss 0.0737 | Def Reward in ep 099|
# |Att Loss 0.0423 | Att Reward in ep 001|
# |Def Estimated: [ 4 19 27 50]| Att Labels: [ 4 19 26 51]
#
# |Epoch 176/500| time: 48.40|
# |Def Loss 0.0734 | Def Reward in ep 096|
# |Att Loss 0.0422 | Att Reward in ep 004|
# |Def Estimated: [10 12 28 50]| Att Labels: [11 11 29 49]
#
# |Epoch 177/500| time: 47.85|
# |Def Loss 0.0730 | Def Reward in ep 097|
# |Att Loss 0.0421 | Att Reward in ep 003|
# |Def Estimated: [ 7 22 30 41]| Att Labels: [ 7 22 31 40]
#
# |Epoch 178/500| time: 45.67|
# |Def Loss 0.0727 | Def Reward in ep 096|
# |Att Loss 0.0420 | Att Reward in ep 004|
# |Def Estimated: [ 8 21 27 44]| Att Labels: [10 21 26 43]
#
# |Epoch 179/500| time: 49.43|
# |Def Loss 0.0724 | Def Reward in ep 093|
# |Att Loss 0.0419 | Att Reward in ep 007|
# |Def Estimated: [ 5 13 30 52]| Att Labels: [ 6 13 30 51]
#
# |Epoch 180/500| time: 48.37|
# |Def Loss 0.0721 | Def Reward in ep 094|
# |Att Loss 0.0418 | Att Reward in ep 006|
# |Def Estimated: [ 9 16 23 52]| Att Labels: [ 8 13 23 56]
#
# |Epoch 181/500| time: 47.13|
# |Def Loss 0.0718 | Def Reward in ep 099|
# |Att Loss 0.0417 | Att Reward in ep 001|
# |Def Estimated: [10 18 21 51]| Att Labels: [10 17 22 51]
#
# |Epoch 182/500| time: 49.77|
# |Def Loss 0.0715 | Def Reward in ep 096|
# |Att Loss 0.0416 | Att Reward in ep 004|
# |Def Estimated: [13 19 21 47]| Att Labels: [10 19 21 50]
#
# |Epoch 183/500| time: 49.52|
# |Def Loss 0.0712 | Def Reward in ep 095|
# |Att Loss 0.0415 | Att Reward in ep 005|
# |Def Estimated: [ 8 15 22 55]| Att Labels: [ 9 17 19 55]
#
# |Epoch 184/500| time: 48.80|
# |Def Loss 0.0708 | Def Reward in ep 094|
# |Att Loss 0.0414 | Att Reward in ep 006|
# |Def Estimated: [12 15 20 53]| Att Labels: [ 8 15 21 56]
#
# |Epoch 185/500| time: 47.71|
# |Def Loss 0.0705 | Def Reward in ep 097|
# |Att Loss 0.0413 | Att Reward in ep 003|
# |Def Estimated: [ 9 12 25 54]| Att Labels: [ 9 12 24 55]
#
# |Epoch 186/500| time: 49.10|
# |Def Loss 0.0701 | Def Reward in ep 093|
# |Att Loss 0.0412 | Att Reward in ep 007|
# |Def Estimated: [10 21 24 45]| Att Labels: [10 21 24 45]
#
# |Epoch 187/500| time: 48.68|
# |Def Loss 0.0698 | Def Reward in ep 096|
# |Att Loss 0.0411 | Att Reward in ep 004|
# |Def Estimated: [15 13 19 53]| Att Labels: [15 13 19 53]
#
# |Epoch 188/500| time: 46.26|
# |Def Loss 0.0695 | Def Reward in ep 098|
# |Att Loss 0.0410 | Att Reward in ep 002|
# |Def Estimated: [ 8 17 23 52]| Att Labels: [ 6 17 24 53]
#
# |Epoch 189/500| time: 47.96|
# |Def Loss 0.0692 | Def Reward in ep 095|
# |Att Loss 0.0410 | Att Reward in ep 005|
# |Def Estimated: [14 21 25 40]| Att Labels: [15 18 27 40]
#
# |Epoch 190/500| time: 50.14|
# |Def Loss 0.0689 | Def Reward in ep 093|
# |Att Loss 0.0409 | Att Reward in ep 007|
# |Def Estimated: [ 8 19 28 45]| Att Labels: [ 4 18 28 50]
#
# |Epoch 191/500| time: 48.58|
# |Def Loss 0.0686 | Def Reward in ep 098|
# |Att Loss 0.0408 | Att Reward in ep 002|
# |Def Estimated: [11 15 21 53]| Att Labels: [11 15 21 53]
#
# |Epoch 192/500| time: 46.90|
# |Def Loss 0.0683 | Def Reward in ep 095|
# |Att Loss 0.0407 | Att Reward in ep 005|
# |Def Estimated: [ 9 20 21 50]| Att Labels: [ 7 20 22 51]
#
# |Epoch 193/500| time: 50.25|
# |Def Loss 0.0680 | Def Reward in ep 096|
# |Att Loss 0.0406 | Att Reward in ep 004|
# |Def Estimated: [12 18 21 49]| Att Labels: [12 17 21 50]
#
# |Epoch 194/500| time: 48.94|
# |Def Loss 0.0677 | Def Reward in ep 097|
# |Att Loss 0.0405 | Att Reward in ep 003|
# |Def Estimated: [11 15 25 49]| Att Labels: [10 14 27 49]
#
# |Epoch 195/500| time: 47.54|
# |Def Loss 0.0674 | Def Reward in ep 096|
# |Att Loss 0.0405 | Att Reward in ep 004|
# |Def Estimated: [ 7 11 31 51]| Att Labels: [ 6 10 31 53]
#
# |Epoch 196/500| time: 47.19|
# |Def Loss 0.0671 | Def Reward in ep 096|
# |Att Loss 0.0404 | Att Reward in ep 004|
# |Def Estimated: [10 24 21 45]| Att Labels: [ 8 24 20 48]
#
# |Epoch 197/500| time: 52.91|
# |Def Loss 0.0668 | Def Reward in ep 095|
# |Att Loss 0.0403 | Att Reward in ep 005|
# |Def Estimated: [ 9 18 33 40]| Att Labels: [ 8 18 31 43]
#
# |Epoch 198/500| time: 47.94|
# |Def Loss 0.0665 | Def Reward in ep 098|
# |Att Loss 0.0402 | Att Reward in ep 002|
# |Def Estimated: [17 18 25 40]| Att Labels: [15 19 25 41]
#
# |Epoch 199/500| time: 46.16|
# |Def Loss 0.0662 | Def Reward in ep 095|
# |Att Loss 0.0401 | Att Reward in ep 005|
# |Def Estimated: [ 9 10 26 55]| Att Labels: [ 7  9 27 57]
#
# |Epoch 200/500| time: 48.44|
# |Def Loss 0.0659 | Def Reward in ep 094|
# |Att Loss 0.0401 | Att Reward in ep 006|
# |Def Estimated: [ 9 18 29 44]| Att Labels: [ 8 17 26 49]
#
# |Epoch 201/500| time: 47.75|
# |Def Loss 0.0657 | Def Reward in ep 094|
# |Att Loss 0.0400 | Att Reward in ep 006|
# |Def Estimated: [16 20 22 42]| Att Labels: [14 18 22 46]
#
# |Epoch 202/500| time: 46.06|
# |Def Loss 0.0654 | Def Reward in ep 092|
# |Att Loss 0.0399 | Att Reward in ep 008|
# |Def Estimated: [12 17 25 46]| Att Labels: [10 17 26 47]
#
# |Epoch 203/500| time: 46.52|
# |Def Loss 0.0652 | Def Reward in ep 096|
# |Att Loss 0.0399 | Att Reward in ep 004|
# |Def Estimated: [ 8 17 28 47]| Att Labels: [ 8 16 26 50]
#
# |Epoch 204/500| time: 47.81|
# |Def Loss 0.0650 | Def Reward in ep 095|
# |Att Loss 0.0398 | Att Reward in ep 005|
# |Def Estimated: [ 8 16 34 42]| Att Labels: [ 8 18 32 42]
#
# |Epoch 205/500| time: 46.48|
# |Def Loss 0.0648 | Def Reward in ep 093|
# |Att Loss 0.0397 | Att Reward in ep 007|
# |Def Estimated: [ 9 16 30 45]| Att Labels: [ 8 18 28 46]
#
# |Epoch 206/500| time: 46.73|
# |Def Loss 0.0646 | Def Reward in ep 096|
# |Att Loss 0.0397 | Att Reward in ep 004|
# |Def Estimated: [12 19 22 47]| Att Labels: [ 9 18 25 48]
#
# |Epoch 207/500| time: 48.57|
# |Def Loss 0.0644 | Def Reward in ep 095|
# |Att Loss 0.0396 | Att Reward in ep 005|
# |Def Estimated: [11 24 21 44]| Att Labels: [ 7 24 23 46]
#
# |Epoch 208/500| time: 47.07|
# |Def Loss 0.0642 | Def Reward in ep 093|
# |Att Loss 0.0396 | Att Reward in ep 007|
# |Def Estimated: [ 9 19 29 43]| Att Labels: [10 18 28 44]
#
# |Epoch 209/500| time: 45.75|
# |Def Loss 0.0640 | Def Reward in ep 095|
# |Att Loss 0.0395 | Att Reward in ep 005|
# |Def Estimated: [11 13 25 51]| Att Labels: [10 11 26 53]
#
# |Epoch 210/500| time: 45.92|
# |Def Loss 0.0639 | Def Reward in ep 097|
# |Att Loss 0.0395 | Att Reward in ep 003|
# |Def Estimated: [ 5 15 24 56]| Att Labels: [ 5 15 25 55]
#
# |Epoch 211/500| time: 47.89|
# |Def Loss 0.0637 | Def Reward in ep 097|
# |Att Loss 0.0394 | Att Reward in ep 003|
# |Def Estimated: [12 17 20 51]| Att Labels: [10 19 20 51]
#
# |Epoch 212/500| time: 47.22|
# |Def Loss 0.0636 | Def Reward in ep 099|
# |Att Loss 0.0394 | Att Reward in ep 001|
# |Def Estimated: [13  8 30 49]| Att Labels: [12  8 30 50]
#
# |Epoch 213/500| time: 44.52|
# |Def Loss 0.0634 | Def Reward in ep 097|
# |Att Loss 0.0393 | Att Reward in ep 003|
# |Def Estimated: [ 3 19 21 57]| Att Labels: [ 3 19 22 56]
#
# |Epoch 214/500| time: 47.01|
# |Def Loss 0.0633 | Def Reward in ep 096|
# |Att Loss 0.0392 | Att Reward in ep 004|
# |Def Estimated: [11  7 30 52]| Att Labels: [11  8 30 51]
#
# |Epoch 215/500| time: 47.74|
# |Def Loss 0.0631 | Def Reward in ep 091|
# |Att Loss 0.0392 | Att Reward in ep 009|
# |Def Estimated: [17 17 30 36]| Att Labels: [17 13 32 38]
#
# |Epoch 216/500| time: 46.97|
# |Def Loss 0.0630 | Def Reward in ep 095|
# |Att Loss 0.0391 | Att Reward in ep 005|
# |Def Estimated: [18 16 30 36]| Att Labels: [15 17 28 40]
#
# |Epoch 217/500| time: 47.81|
# |Def Loss 0.0628 | Def Reward in ep 094|
# |Att Loss 0.0391 | Att Reward in ep 006|
# |Def Estimated: [12 15 30 43]| Att Labels: [12 16 33 39]
#
# |Epoch 218/500| time: 47.07|
# |Def Loss 0.0627 | Def Reward in ep 097|
# |Att Loss 0.0390 | Att Reward in ep 003|
# |Def Estimated: [ 8 19 17 56]| Att Labels: [ 7 17 18 58]
#
# |Epoch 219/500| time: 46.62|
# |Def Loss 0.0625 | Def Reward in ep 097|
# |Att Loss 0.0389 | Att Reward in ep 003|
# |Def Estimated: [10 15 21 54]| Att Labels: [ 9 14 22 55]
#
# |Epoch 220/500| time: 44.33|
# |Def Loss 0.0623 | Def Reward in ep 095|
# |Att Loss 0.0389 | Att Reward in ep 005|
# |Def Estimated: [ 8 18 28 46]| Att Labels: [10 16 27 47]
#
# |Epoch 221/500| time: 48.20|
# |Def Loss 0.0622 | Def Reward in ep 095|
# |Att Loss 0.0388 | Att Reward in ep 005|
# |Def Estimated: [ 8 17 29 46]| Att Labels: [ 8 14 28 50]
#
# |Epoch 222/500| time: 47.75|
# |Def Loss 0.0620 | Def Reward in ep 095|
# |Att Loss 0.0388 | Att Reward in ep 005|
# |Def Estimated: [13 12 25 50]| Att Labels: [12 11 26 51]
#
# |Epoch 223/500| time: 46.35|
# |Def Loss 0.0619 | Def Reward in ep 097|
# |Att Loss 0.0387 | Att Reward in ep 003|
# |Def Estimated: [ 7 19 24 50]| Att Labels: [ 6 19 23 52]
#
# |Epoch 224/500| time: 45.88|
# |Def Loss 0.0617 | Def Reward in ep 094|
# |Att Loss 0.0387 | Att Reward in ep 006|
# |Def Estimated: [ 8 12 30 50]| Att Labels: [10  9 30 51]
#
# |Epoch 225/500| time: 47.95|
# |Def Loss 0.0616 | Def Reward in ep 099|
# |Att Loss 0.0386 | Att Reward in ep 001|
# |Def Estimated: [11  8 26 55]| Att Labels: [11  9 25 55]
#
# |Epoch 226/500| time: 46.03|
# |Def Loss 0.0614 | Def Reward in ep 095|
# |Att Loss 0.0386 | Att Reward in ep 005|
# |Def Estimated: [10 19 31 40]| Att Labels: [ 8 18 30 44]
#
# |Epoch 227/500| time: 44.94|
# |Def Loss 0.0612 | Def Reward in ep 095|
# |Att Loss 0.0385 | Att Reward in ep 005|
# |Def Estimated: [ 8 12 24 56]| Att Labels: [10 14 20 56]
#
# |Epoch 228/500| time: 46.93|
# |Def Loss 0.0611 | Def Reward in ep 095|
# |Att Loss 0.0384 | Att Reward in ep 005|
# |Def Estimated: [12 13 35 40]| Att Labels: [10 14 35 41]
#
# |Epoch 229/500| time: 46.11|
# |Def Loss 0.0609 | Def Reward in ep 094|
# |Att Loss 0.0384 | Att Reward in ep 006|
# |Def Estimated: [10 18 27 45]| Att Labels: [ 9 16 25 50]
#
# |Epoch 230/500| time: 46.56|
# |Def Loss 0.0608 | Def Reward in ep 096|
# |Att Loss 0.0383 | Att Reward in ep 004|
# |Def Estimated: [10 17 32 41]| Att Labels: [ 9 18 29 44]
#
# |Epoch 231/500| time: 47.98|
# |Def Loss 0.0607 | Def Reward in ep 097|
# |Att Loss 0.0383 | Att Reward in ep 003|
# |Def Estimated: [10 24 22 44]| Att Labels: [10 22 23 45]
#
# |Epoch 232/500| time: 47.56|
# |Def Loss 0.0605 | Def Reward in ep 099|
# |Att Loss 0.0382 | Att Reward in ep 001|
# |Def Estimated: [10 18 21 51]| Att Labels: [ 9 18 22 51]
#
# |Epoch 233/500| time: 45.94|
# |Def Loss 0.0603 | Def Reward in ep 093|
# |Att Loss 0.0382 | Att Reward in ep 007|
# |Def Estimated: [14 21 22 43]| Att Labels: [16 19 21 44]
#
# |Epoch 234/500| time: 46.03|
# |Def Loss 0.0602 | Def Reward in ep 097|
# |Att Loss 0.0381 | Att Reward in ep 003|
# |Def Estimated: [ 7 20 31 42]| Att Labels: [ 6 20 31 43]
#
# |Epoch 235/500| time: 48.95|
# |Def Loss 0.0600 | Def Reward in ep 093|
# |Att Loss 0.0381 | Att Reward in ep 007|
# |Def Estimated: [16 27 22 35]| Att Labels: [14 25 21 40]
#
# |Epoch 236/500| time: 47.20|
# |Def Loss 0.0599 | Def Reward in ep 095|
# |Att Loss 0.0380 | Att Reward in ep 005|
# |Def Estimated: [11 20 28 41]| Att Labels: [11 17 29 43]
#
# |Epoch 237/500| time: 45.88|
# |Def Loss 0.0597 | Def Reward in ep 092|
# |Att Loss 0.0379 | Att Reward in ep 008|
# |Def Estimated: [ 9 16 26 49]| Att Labels: [ 8 16 26 50]
#
# |Epoch 238/500| time: 46.65|
# |Def Loss 0.0596 | Def Reward in ep 096|
# |Att Loss 0.0379 | Att Reward in ep 004|
# |Def Estimated: [16  9 20 55]| Att Labels: [16  8 19 57]
#
# |Epoch 239/500| time: 47.74|
# |Def Loss 0.0594 | Def Reward in ep 092|
# |Att Loss 0.0378 | Att Reward in ep 008|
# |Def Estimated: [11 18 19 52]| Att Labels: [10 15 22 53]
#
# |Epoch 240/500| time: 46.00|
# |Def Loss 0.0592 | Def Reward in ep 096|
# |Att Loss 0.0378 | Att Reward in ep 004|
# |Def Estimated: [10 13 27 50]| Att Labels: [10 14 25 51]
#
# |Epoch 241/500| time: 44.98|
# |Def Loss 0.0590 | Def Reward in ep 097|
# |Att Loss 0.0377 | Att Reward in ep 003|
# |Def Estimated: [ 3 21 17 59]| Att Labels: [ 3 20 16 61]
#
# |Epoch 242/500| time: 47.45|
# |Def Loss 0.0588 | Def Reward in ep 096|
# |Att Loss 0.0377 | Att Reward in ep 004|
# |Def Estimated: [14 16 17 53]| Att Labels: [14 15 17 54]
#
# |Epoch 243/500| time: 46.65|
# |Def Loss 0.0587 | Def Reward in ep 092|
# |Att Loss 0.0377 | Att Reward in ep 008|
# |Def Estimated: [ 9 12 24 55]| Att Labels: [10 10 25 55]
#
# |Epoch 244/500| time: 45.42|
# |Def Loss 0.0585 | Def Reward in ep 095|
# |Att Loss 0.0376 | Att Reward in ep 005|
# |Def Estimated: [11 22 22 45]| Att Labels: [12 20 24 44]
#
# |Epoch 245/500| time: 46.88|
# |Def Loss 0.0584 | Def Reward in ep 098|
# |Att Loss 0.0376 | Att Reward in ep 002|
# |Def Estimated: [12 15 25 48]| Att Labels: [13 14 26 47]
#
# |Epoch 246/500| time: 48.14|
# |Def Loss 0.0583 | Def Reward in ep 098|
# |Att Loss 0.0375 | Att Reward in ep 002|
# |Def Estimated: [ 9  7 30 54]| Att Labels: [10  8 28 54]
#
# |Epoch 247/500| time: 45.32|
# |Def Loss 0.0581 | Def Reward in ep 094|
# |Att Loss 0.0375 | Att Reward in ep 006|
# |Def Estimated: [13 17 31 39]| Att Labels: [11 18 31 40]
#
# |Epoch 248/500| time: 45.16|
# |Def Loss 0.0580 | Def Reward in ep 097|
# |Att Loss 0.0374 | Att Reward in ep 003|
# |Def Estimated: [10 14 26 50]| Att Labels: [10 15 26 49]
#
# |Epoch 249/500| time: 47.79|
# |Def Loss 0.0578 | Def Reward in ep 098|
# |Att Loss 0.0374 | Att Reward in ep 002|
# |Def Estimated: [17  7 28 48]| Att Labels: [16  7 29 48]
#
# |Epoch 250/500| time: 48.10|
# |Def Loss 0.0577 | Def Reward in ep 094|
# |Att Loss 0.0373 | Att Reward in ep 006|
# |Def Estimated: [11 12 27 50]| Att Labels: [11 11 26 52]
#
# |Epoch 251/500| time: 46.47|
# |Def Loss 0.0575 | Def Reward in ep 096|
# |Att Loss 0.0373 | Att Reward in ep 004|
# |Def Estimated: [15 14 30 41]| Att Labels: [15 13 30 42]
#
# |Epoch 252/500| time: 46.72|
# |Def Loss 0.0573 | Def Reward in ep 097|
# |Att Loss 0.0372 | Att Reward in ep 003|
# |Def Estimated: [ 9 20 28 43]| Att Labels: [ 8 19 29 44]
#
# |Epoch 253/500| time: 47.74|
# |Def Loss 0.0571 | Def Reward in ep 094|
# |Att Loss 0.0372 | Att Reward in ep 006|
# |Def Estimated: [11 15 25 49]| Att Labels: [12 15 26 47]
#
# |Epoch 254/500| time: 46.07|
# |Def Loss 0.0569 | Def Reward in ep 095|
# |Att Loss 0.0371 | Att Reward in ep 005|
# |Def Estimated: [10 11 25 54]| Att Labels: [ 8 10 28 54]
#
# |Epoch 255/500| time: 45.70|
# |Def Loss 0.0568 | Def Reward in ep 097|
# |Att Loss 0.0371 | Att Reward in ep 003|
# |Def Estimated: [ 9 13 23 55]| Att Labels: [ 9 14 23 54]
#
# |Epoch 256/500| time: 47.37|
# |Def Loss 0.0566 | Def Reward in ep 093|
# |Att Loss 0.0371 | Att Reward in ep 007|
# |Def Estimated: [11 15 27 47]| Att Labels: [12 16 25 47]
#
# |Epoch 257/500| time: 46.96|
# |Def Loss 0.0564 | Def Reward in ep 095|
# |Att Loss 0.0370 | Att Reward in ep 005|
# |Def Estimated: [12 15 19 54]| Att Labels: [11 13 20 56]
#
# |Epoch 258/500| time: 45.99|
# |Def Loss 0.0563 | Def Reward in ep 099|
# |Att Loss 0.0370 | Att Reward in ep 001|
# |Def Estimated: [10 12 28 50]| Att Labels: [ 9 12 29 50]
#
# |Epoch 259/500| time: 46.33|
# |Def Loss 0.0561 | Def Reward in ep 095|
# |Att Loss 0.0369 | Att Reward in ep 005|
# |Def Estimated: [ 9 20 20 51]| Att Labels: [ 9 21 22 48]
#
# |Epoch 260/500| time: 48.05|
# |Def Loss 0.0559 | Def Reward in ep 097|
# |Att Loss 0.0369 | Att Reward in ep 003|
# |Def Estimated: [12 14 30 44]| Att Labels: [12 14 31 43]
#
# |Epoch 261/500| time: 45.00|
# |Def Loss 0.0557 | Def Reward in ep 096|
# |Att Loss 0.0368 | Att Reward in ep 004|
# |Def Estimated: [ 7 15 24 54]| Att Labels: [ 8 16 21 55]
#
# |Epoch 262/500| time: 44.92|
# |Def Loss 0.0555 | Def Reward in ep 094|
# |Att Loss 0.0368 | Att Reward in ep 006|
# |Def Estimated: [22 19 20 39]| Att Labels: [16 20 21 43]
#
# |Epoch 263/500| time: 48.22|
# |Def Loss 0.0553 | Def Reward in ep 097|
# |Att Loss 0.0367 | Att Reward in ep 003|
# |Def Estimated: [14 17 24 45]| Att Labels: [14 19 25 42]
#
# |Epoch 264/500| time: 46.90|
# |Def Loss 0.0552 | Def Reward in ep 098|
# |Att Loss 0.0367 | Att Reward in ep 002|
# |Def Estimated: [11 16 30 43]| Att Labels: [10 16 31 43]
#
# |Epoch 265/500| time: 45.06|
# |Def Loss 0.0551 | Def Reward in ep 090|
# |Att Loss 0.0366 | Att Reward in ep 010|
# |Def Estimated: [12 15 20 53]| Att Labels: [15 13 20 52]
#
# |Epoch 266/500| time: 47.88|
# |Def Loss 0.0550 | Def Reward in ep 099|
# |Att Loss 0.0366 | Att Reward in ep 001|
# |Def Estimated: [ 9 16 26 49]| Att Labels: [ 9 15 26 50]
#
# |Epoch 267/500| time: 47.68|
# |Def Loss 0.0549 | Def Reward in ep 095|
# |Att Loss 0.0365 | Att Reward in ep 005|
# |Def Estimated: [15 13 26 46]| Att Labels: [16 14 22 48]
#
# |Epoch 268/500| time: 46.06|
# |Def Loss 0.0548 | Def Reward in ep 097|
# |Att Loss 0.0364 | Att Reward in ep 003|
# |Def Estimated: [11 14 22 53]| Att Labels: [12 14 22 52]
#
# |Epoch 269/500| time: 44.50|
# |Def Loss 0.0546 | Def Reward in ep 093|
# |Att Loss 0.0364 | Att Reward in ep 007|
# |Def Estimated: [11 14 29 46]| Att Labels: [ 9 13 27 51]
#
# |Epoch 270/500| time: 49.06|
# |Def Loss 0.0544 | Def Reward in ep 096|
# |Att Loss 0.0363 | Att Reward in ep 004|
# |Def Estimated: [13 17 30 40]| Att Labels: [11 18 30 41]
#
# |Epoch 271/500| time: 46.31|
# |Def Loss 0.0544 | Def Reward in ep 097|
# |Att Loss 0.0363 | Att Reward in ep 003|
# |Def Estimated: [11 13 24 52]| Att Labels: [10 12 25 53]
#
# |Epoch 272/500| time: 46.81|
# |Def Loss 0.0542 | Def Reward in ep 097|
# |Att Loss 0.0362 | Att Reward in ep 003|
# |Def Estimated: [16 17 24 43]| Att Labels: [17 15 25 43]
#
# |Epoch 273/500| time: 48.08|
# |Def Loss 0.0541 | Def Reward in ep 093|
# |Att Loss 0.0362 | Att Reward in ep 007|
# |Def Estimated: [12 14 29 45]| Att Labels: [ 9 13 28 50]
#
# |Epoch 274/500| time: 50.04|
# |Def Loss 0.0539 | Def Reward in ep 100|
# |Att Loss 0.0361 | Att Reward in ep 000|
# |Def Estimated: [16 18 28 38]| Att Labels: [16 18 28 38]
#
# |Epoch 275/500| time: 46.92|
# |Def Loss 0.0538 | Def Reward in ep 098|
# |Att Loss 0.0361 | Att Reward in ep 002|
# |Def Estimated: [10 14 33 43]| Att Labels: [11 15 32 42]
#
# |Epoch 276/500| time: 44.79|
# |Def Loss 0.0536 | Def Reward in ep 095|
# |Att Loss 0.0360 | Att Reward in ep 005|
# |Def Estimated: [ 8 16 36 40]| Att Labels: [ 9 16 36 39]
#
# |Epoch 277/500| time: 49.08|
# |Def Loss 0.0535 | Def Reward in ep 098|
# |Att Loss 0.0360 | Att Reward in ep 002|
# ...
# |Att Loss 0.0316 | Att Reward in ep 006|
# |Def Estimated: [15 14 26 45]| Att Labels: [13 14 28 45]
#
# |Epoch 406/500| time: 47.66|
# |Def Loss 0.0404 | Def Reward in ep 096|
# |Att Loss 0.0316 | Att Reward in ep 004|
# |Def Estimated: [ 9 30 18 43]| Att Labels: [10 26 19 45]
#
# |Epoch 407/500| time: 47.58|
# |Def Loss 0.0403 | Def Reward in ep 098|
# |Att Loss 0.0316 | Att Reward in ep 002|
# |Def Estimated: [13  6 24 57]| Att Labels: [12  6 25 57]
#
# |Epoch 408/500| time: 45.98|
# |Def Loss 0.0403 | Def Reward in ep 094|
# |Att Loss 0.0316 | Att Reward in ep 006|
# |Def Estimated: [10 15 28 47]| Att Labels: [10 13 29 48]
#
# |Epoch 409/500| time: 46.65|
# |Def Loss 0.0402 | Def Reward in ep 097|
# |Att Loss 0.0315 | Att Reward in ep 003|
# |Def Estimated: [10 11 34 45]| Att Labels: [ 9 12 32 47]
#
# |Epoch 410/500| time: 47.90|
# |Def Loss 0.0402 | Def Reward in ep 097|
# |Att Loss 0.0315 | Att Reward in ep 003|
# |Def Estimated: [11 21 26 42]| Att Labels: [12 19 26 43]
#
# |Epoch 411/500| time: 45.15|
# |Def Loss 0.0402 | Def Reward in ep 097|
# |Att Loss 0.0315 | Att Reward in ep 003|
# |Def Estimated: [13 17 28 42]| Att Labels: [12 19 26 43]
#
# |Epoch 412/500| time: 45.28|
# |Def Loss 0.0402 | Def Reward in ep 091|
# |Att Loss 0.0315 | Att Reward in ep 009|
# |Def Estimated: [18 25 20 37]| Att Labels: [14 23 20 43]
#
# |Epoch 413/500| time: 48.99|
# |Def Loss 0.0401 | Def Reward in ep 099|
# |Att Loss 0.0314 | Att Reward in ep 001|
# |Def Estimated: [10 21 20 49]| Att Labels: [ 9 21 20 50]
#
# |Epoch 414/500| time: 48.21|
# |Def Loss 0.0401 | Def Reward in ep 097|
# |Att Loss 0.0314 | Att Reward in ep 003|
# |Def Estimated: [17 19 27 37]| Att Labels: [18 18 25 39]
#
# |Epoch 415/500| time: 49.13|
# |Def Loss 0.0401 | Def Reward in ep 097|
# |Att Loss 0.0314 | Att Reward in ep 003|
# |Def Estimated: [ 9 21 29 41]| Att Labels: [ 9 21 27 43]
#
# |Epoch 416/500| time: 47.24|
# |Def Loss 0.0400 | Def Reward in ep 096|
# |Att Loss 0.0314 | Att Reward in ep 004|
# |Def Estimated: [17 12 21 50]| Att Labels: [14 13 21 52]
#
# |Epoch 417/500| time: 48.74|
# |Def Loss 0.0399 | Def Reward in ep 094|
# |Att Loss 0.0313 | Att Reward in ep 006|
# |Def Estimated: [17 14 26 43]| Att Labels: [14 14 28 44]
#
# |Epoch 418/500| time: 47.45|
# |Def Loss 0.0399 | Def Reward in ep 097|
# |Att Loss 0.0313 | Att Reward in ep 003|
# |Def Estimated: [13 20 25 42]| Att Labels: [13 18 26 43]
#
# |Epoch 419/500| time: 46.18|
# |Def Loss 0.0398 | Def Reward in ep 093|
# |Att Loss 0.0313 | Att Reward in ep 007|
# |Def Estimated: [14 15 29 42]| Att Labels: [16 15 29 40]
#
# |Epoch 420/500| time: 48.33|
# |Def Loss 0.0397 | Def Reward in ep 097|
# |Att Loss 0.0313 | Att Reward in ep 003|
# |Def Estimated: [13 21 26 40]| Att Labels: [12 22 26 40]
#
# |Epoch 421/500| time: 47.24|
# |Def Loss 0.0397 | Def Reward in ep 097|
# |Att Loss 0.0313 | Att Reward in ep 003|
# |Def Estimated: [ 8 16 28 48]| Att Labels: [ 9 15 26 50]
#
# |Epoch 422/500| time: 45.97|
# |Def Loss 0.0396 | Def Reward in ep 093|
# |Att Loss 0.0312 | Att Reward in ep 007|
# |Def Estimated: [ 8 22 26 44]| Att Labels: [ 8 20 28 44]
#
# |Epoch 423/500| time: 45.05|
# |Def Loss 0.0395 | Def Reward in ep 096|
# |Att Loss 0.0312 | Att Reward in ep 004|
# |Def Estimated: [ 5 12 27 56]| Att Labels: [ 4 13 28 55]
#
# |Epoch 424/500| time: 48.09|
# |Def Loss 0.0395 | Def Reward in ep 097|
# |Att Loss 0.0312 | Att Reward in ep 003|
# |Def Estimated: [14 12 22 52]| Att Labels: [13 12 21 54]
#
# |Epoch 425/500| time: 47.53|
# |Def Loss 0.0394 | Def Reward in ep 100|
# |Att Loss 0.0312 | Att Reward in ep 000|
# |Def Estimated: [19  9 28 44]| Att Labels: [19  9 28 44]
#
# |Epoch 426/500| time: 46.37|
# |Def Loss 0.0393 | Def Reward in ep 096|
# |Att Loss 0.0312 | Att Reward in ep 004|
# |Def Estimated: [10 20 23 47]| Att Labels: [ 8 20 26 46]
#
# |Epoch 427/500| time: 48.89|
# |Def Loss 0.0392 | Def Reward in ep 094|
# |Att Loss 0.0311 | Att Reward in ep 006|
# |Def Estimated: [12 18 25 45]| Att Labels: [13 18 26 43]
#
# |Epoch 428/500| time: 48.74|
# |Def Loss 0.0392 | Def Reward in ep 098|
# |Att Loss 0.0311 | Att Reward in ep 002|
# |Def Estimated: [13 18 28 41]| Att Labels: [13 18 28 41]
#
# |Epoch 429/500| time: 46.46|
# |Def Loss 0.0391 | Def Reward in ep 097|
# |Att Loss 0.0311 | Att Reward in ep 003|
# |Def Estimated: [10 21 24 45]| Att Labels: [10 22 23 45]
#
# |Epoch 430/500| time: 45.40|
# |Def Loss 0.0390 | Def Reward in ep 097|
# |Att Loss 0.0311 | Att Reward in ep 003|
# |Def Estimated: [ 9 22 19 50]| Att Labels: [ 9 20 19 52]
#
# |Epoch 431/500| time: 47.62|
# |Def Loss 0.0389 | Def Reward in ep 093|
# |Att Loss 0.0311 | Att Reward in ep 007|
# |Def Estimated: [16 19 24 41]| Att Labels: [16 17 28 39]
#
# |Epoch 432/500| time: 46.78|
# |Def Loss 0.0389 | Def Reward in ep 098|
# |Att Loss 0.0310 | Att Reward in ep 002|
# |Def Estimated: [14 17 19 50]| Att Labels: [13 17 18 52]
#
# |Epoch 433/500| time: 44.86|
# |Def Loss 0.0389 | Def Reward in ep 095|
# |Att Loss 0.0310 | Att Reward in ep 005|
# |Def Estimated: [15 21 26 38]| Att Labels: [15 19 26 40]
#
# |Epoch 434/500| time: 47.64|
# |Def Loss 0.0388 | Def Reward in ep 091|
# |Att Loss 0.0310 | Att Reward in ep 009|
# |Def Estimated: [17 18 27 38]| Att Labels: [17 17 25 41]
#
# |Epoch 435/500| time: 46.88|
# |Def Loss 0.0388 | Def Reward in ep 097|
# |Att Loss 0.0310 | Att Reward in ep 003|
# |Def Estimated: [13 28 23 36]| Att Labels: [13 28 22 37]
#
# |Epoch 436/500| time: 45.50|
# |Def Loss 0.0387 | Def Reward in ep 097|
# |Att Loss 0.0309 | Att Reward in ep 003|
# |Def Estimated: [ 9 22 30 39]| Att Labels: [ 9 20 30 41]
#
# |Epoch 437/500| time: 45.27|
# |Def Loss 0.0387 | Def Reward in ep 091|
# |Att Loss 0.0309 | Att Reward in ep 009|
# |Def Estimated: [ 9 20 25 46]| Att Labels: [ 7 15 25 53]
#
# |Epoch 438/500| time: 48.06|
# |Def Loss 0.0386 | Def Reward in ep 096|
# |Att Loss 0.0309 | Att Reward in ep 004|
# |Def Estimated: [13 18 22 47]| Att Labels: [13 17 22 48]
#
# |Epoch 439/500| time: 46.10|
# |Def Loss 0.0386 | Def Reward in ep 089|
# |Att Loss 0.0309 | Att Reward in ep 011|
# |Def Estimated: [11 20 21 48]| Att Labels: [13 16 24 47]
#
# |Epoch 440/500| time: 45.71|
# |Def Loss 0.0385 | Def Reward in ep 097|
# |Att Loss 0.0309 | Att Reward in ep 003|
# |Def Estimated: [22 14 18 46]| Att Labels: [21 14 18 47]
#
# |Epoch 441/500| time: 47.68|
# |Def Loss 0.0385 | Def Reward in ep 094|
# |Att Loss 0.0308 | Att Reward in ep 006|
# |Def Estimated: [17 21 15 47]| Att Labels: [16 23 12 49]
#
# |Epoch 442/500| time: 47.24|
# |Def Loss 0.0384 | Def Reward in ep 096|
# |Att Loss 0.0308 | Att Reward in ep 004|
# |Def Estimated: [16 17 19 48]| Att Labels: [18 16 20 46]
#
# |Epoch 443/500| time: 43.93|
# |Def Loss 0.0383 | Def Reward in ep 093|
# |Att Loss 0.0308 | Att Reward in ep 007|
# |Def Estimated: [11 22 22 45]| Att Labels: [ 9 22 21 48]
#
# |Epoch 444/500| time: 45.66|
# |Def Loss 0.0383 | Def Reward in ep 094|
# |Att Loss 0.0308 | Att Reward in ep 006|
# |Def Estimated: [18 15 22 45]| Att Labels: [15 16 21 48]
#
# |Epoch 445/500| time: 47.34|
# |Def Loss 0.0382 | Def Reward in ep 096|
# |Att Loss 0.0308 | Att Reward in ep 004|
# |Def Estimated: [17 15 23 45]| Att Labels: [14 15 24 47]
#
# |Epoch 446/500| time: 45.58|
# |Def Loss 0.0382 | Def Reward in ep 096|
# |Att Loss 0.0308 | Att Reward in ep 004|
# |Def Estimated: [ 9 20 25 46]| Att Labels: [ 8 19 25 48]
#
# |Epoch 447/500| time: 43.64|
# |Def Loss 0.0381 | Def Reward in ep 097|
# |Att Loss 0.0308 | Att Reward in ep 003|
# |Def Estimated: [11 20 24 45]| Att Labels: [11 19 23 47]
#
# |Epoch 448/500| time: 47.25|
# |Def Loss 0.0380 | Def Reward in ep 095|
# |Att Loss 0.0308 | Att Reward in ep 005|
# |Def Estimated: [14 22 21 43]| Att Labels: [11 23 21 45]
#
# |Epoch 449/500| time: 47.23|
# |Def Loss 0.0380 | Def Reward in ep 096|
# |Att Loss 0.0308 | Att Reward in ep 004|
# |Def Estimated: [20 17 24 39]| Att Labels: [18 17 24 41]
#
# |Epoch 450/500| time: 44.92|
# |Def Loss 0.0379 | Def Reward in ep 095|
# |Att Loss 0.0307 | Att Reward in ep 005|
# |Def Estimated: [14 20 21 45]| Att Labels: [13 19 22 46]
#
# |Epoch 451/500| time: 46.20|
# |Def Loss 0.0378 | Def Reward in ep 098|
# |Att Loss 0.0307 | Att Reward in ep 002|
# |Def Estimated: [18 15 24 43]| Att Labels: [19 14 23 44]
#
# |Epoch 452/500| time: 48.28|
# |Def Loss 0.0378 | Def Reward in ep 093|
# |Att Loss 0.0307 | Att Reward in ep 007|
# |Def Estimated: [13 19 20 48]| Att Labels: [11 18 23 48]
#
# |Epoch 453/500| time: 47.06|
# |Def Loss 0.0378 | Def Reward in ep 096|
# |Att Loss 0.0307 | Att Reward in ep 004|
# |Def Estimated: [15 17 22 46]| Att Labels: [13 17 24 46]
#
# |Epoch 454/500| time: 45.30|
# |Def Loss 0.0377 | Def Reward in ep 097|
# |Att Loss 0.0307 | Att Reward in ep 003|
# |Def Estimated: [13 17 28 42]| Att Labels: [12 16 29 43]
#
# |Epoch 455/500| time: 48.46|
# |Def Loss 0.0376 | Def Reward in ep 095|
# |Att Loss 0.0307 | Att Reward in ep 005|
# |Def Estimated: [18 20 27 35]| Att Labels: [17 20 29 34]
#
# |Epoch 456/500| time: 45.61|
# |Def Loss 0.0376 | Def Reward in ep 094|
# |Att Loss 0.0306 | Att Reward in ep 006|
# |Def Estimated: [19 17 22 42]| Att Labels: [19 17 22 42]
#
# |Epoch 457/500| time: 46.95|
# |Def Loss 0.0376 | Def Reward in ep 097|
# |Att Loss 0.0306 | Att Reward in ep 003|
# |Def Estimated: [11 15 24 50]| Att Labels: [13 13 23 51]
#
# |Epoch 458/500| time: 48.15|
# |Def Loss 0.0375 | Def Reward in ep 098|
# |Att Loss 0.0306 | Att Reward in ep 002|
# |Def Estimated: [24 13 20 43]| Att Labels: [22 13 22 43]
#
# |Epoch 459/500| time: 50.46|
# |Def Loss 0.0375 | Def Reward in ep 098|
# |Att Loss 0.0306 | Att Reward in ep 002|
# |Def Estimated: [13 15 26 46]| Att Labels: [14 14 27 45]
#
# |Epoch 460/500| time: 47.42|
# |Def Loss 0.0374 | Def Reward in ep 095|
# |Att Loss 0.0306 | Att Reward in ep 005|
# |Def Estimated: [14 16 27 43]| Att Labels: [13 14 28 45]
#
# |Epoch 461/500| time: 46.89|
# |Def Loss 0.0373 | Def Reward in ep 096|
# |Att Loss 0.0306 | Att Reward in ep 004|
# |Def Estimated: [13  9 27 51]| Att Labels: [12  9 25 54]
#
# |Epoch 462/500| time: 51.04|
# |Def Loss 0.0373 | Def Reward in ep 097|
# |Att Loss 0.0306 | Att Reward in ep 003|
# |Def Estimated: [16 19 20 45]| Att Labels: [16 18 21 45]
#
# |Epoch 463/500| time: 50.94|
# |Def Loss 0.0372 | Def Reward in ep 097|
# |Att Loss 0.0306 | Att Reward in ep 003|
# |Def Estimated: [15 14 22 49]| Att Labels: [15 14 22 49]
#
# |Epoch 464/500| time: 51.21|
# |Def Loss 0.0371 | Def Reward in ep 097|
# |Att Loss 0.0305 | Att Reward in ep 003|
# |Def Estimated: [16 15 23 46]| Att Labels: [15 14 24 47]
#
# |Epoch 465/500| time: 51.89|
# |Def Loss 0.0371 | Def Reward in ep 096|
# |Att Loss 0.0305 | Att Reward in ep 004|
# |Def Estimated: [ 9 18 25 48]| Att Labels: [ 8 18 25 49]
#
# |Epoch 466/500| time: 56.48|
# |Def Loss 0.0370 | Def Reward in ep 094|
# |Att Loss 0.0305 | Att Reward in ep 006|
# |Def Estimated: [15 20 16 49]| Att Labels: [14 19 17 50]
#
# |Epoch 467/500| time: 48.64|
# |Def Loss 0.0369 | Def Reward in ep 095|
# |Att Loss 0.0305 | Att Reward in ep 005|
# |Def Estimated: [10 18 30 42]| Att Labels: [10 19 30 41]
#
# |Epoch 468/500| time: 44.31|
# |Def Loss 0.0369 | Def Reward in ep 093|
# |Att Loss 0.0305 | Att Reward in ep 007|
# |Def Estimated: [14 20 18 48]| Att Labels: [15 16 18 51]
#
# |Epoch 469/500| time: 48.91|
# |Def Loss 0.0368 | Def Reward in ep 095|
# |Att Loss 0.0305 | Att Reward in ep 005|
# |Def Estimated: [17 13 21 49]| Att Labels: [17 12 20 51]
#
# |Epoch 470/500| time: 47.29|
# |Def Loss 0.0367 | Def Reward in ep 096|
# |Att Loss 0.0305 | Att Reward in ep 004|
# |Def Estimated: [16 12 23 49]| Att Labels: [16 12 21 51]
#
# |Epoch 471/500| time: 46.04|
# |Def Loss 0.0367 | Def Reward in ep 098|
# |Att Loss 0.0304 | Att Reward in ep 002|
# |Def Estimated: [16 14 21 49]| Att Labels: [16 14 23 47]
#
# |Epoch 472/500| time: 47.98|
# |Def Loss 0.0367 | Def Reward in ep 095|
# |Att Loss 0.0304 | Att Reward in ep 005|
# |Def Estimated: [11 15 24 50]| Att Labels: [ 9 14 24 53]
#
# |Epoch 473/500| time: 49.33|
# |Def Loss 0.0366 | Def Reward in ep 093|
# |Att Loss 0.0304 | Att Reward in ep 007|
# |Def Estimated: [10 18 23 49]| Att Labels: [ 8 17 23 52]
#
# |Epoch 474/500| time: 47.21|
# |Def Loss 0.0365 | Def Reward in ep 095|
# |Att Loss 0.0304 | Att Reward in ep 005|
# |Def Estimated: [14 15 23 48]| Att Labels: [13 15 24 48]
#
# |Epoch 475/500| time: 44.81|
# |Def Loss 0.0365 | Def Reward in ep 097|
# |Att Loss 0.0304 | Att Reward in ep 003|
# |Def Estimated: [16 17 19 48]| Att Labels: [15 18 19 48]
#
# |Epoch 476/500| time: 49.29|
# |Def Loss 0.0364 | Def Reward in ep 095|
# |Att Loss 0.0304 | Att Reward in ep 005|
# |Def Estimated: [13 21 22 44]| Att Labels: [13 22 19 46]
#
# |Epoch 477/500| time: 49.24|
# |Def Loss 0.0363 | Def Reward in ep 095|
# |Att Loss 0.0303 | Att Reward in ep 005|
# |Def Estimated: [14 21 24 41]| Att Labels: [14 20 25 41]
#
# |Epoch 478/500| time: 45.88|
# |Def Loss 0.0362 | Def Reward in ep 096|
# |Att Loss 0.0303 | Att Reward in ep 004|
# |Def Estimated: [18 14 28 40]| Att Labels: [17 13 28 42]
#
# |Epoch 479/500| time: 47.27|
# |Def Loss 0.0362 | Def Reward in ep 093|
# |Att Loss 0.0303 | Att Reward in ep 007|
# |Def Estimated: [16 21 21 42]| Att Labels: [17 20 23 40]
#
# |Epoch 480/500| time: 49.44|
# |Def Loss 0.0361 | Def Reward in ep 095|
# |Att Loss 0.0303 | Att Reward in ep 005|
# |Def Estimated: [11 11 32 46]| Att Labels: [11 10 29 50]
#
# |Epoch 481/500| time: 48.43|
# |Def Loss 0.0360 | Def Reward in ep 095|
# |Att Loss 0.0303 | Att Reward in ep 005|
# |Def Estimated: [16 17 25 42]| Att Labels: [17 15 25 43]
#
# |Epoch 482/500| time: 45.29|
# |Def Loss 0.0360 | Def Reward in ep 095|
# |Att Loss 0.0303 | Att Reward in ep 005|
# |Def Estimated: [15 14 27 44]| Att Labels: [12 15 27 46]
#
# |Epoch 483/500| time: 50.89|
# |Def Loss 0.0359 | Def Reward in ep 093|
# |Att Loss 0.0303 | Att Reward in ep 007|
# |Def Estimated: [18  8 28 46]| Att Labels: [16  9 26 49]
#
# |Epoch 484/500| time: 47.17|
# |Def Loss 0.0358 | Def Reward in ep 098|
# |Att Loss 0.0303 | Att Reward in ep 002|
# |Def Estimated: [15 22 22 41]| Att Labels: [16 21 23 40]
#
# |Epoch 485/500| time: 46.47|
# |Def Loss 0.0358 | Def Reward in ep 095|
# |Att Loss 0.0302 | Att Reward in ep 005|
# |Def Estimated: [18 19 18 45]| Att Labels: [18 16 19 47]
#
# |Epoch 486/500| time: 47.29|
# |Def Loss 0.0357 | Def Reward in ep 097|
# |Att Loss 0.0302 | Att Reward in ep 003|
# |Def Estimated: [15 10 22 53]| Att Labels: [14 11 22 53]
#
# |Epoch 487/500| time: 48.89|
# |Def Loss 0.0357 | Def Reward in ep 096|
# |Att Loss 0.0302 | Att Reward in ep 004|
# |Def Estimated: [13 13 26 48]| Att Labels: [12 14 26 48]
#
# |Epoch 488/500| time: 48.51|
# |Def Loss 0.0356 | Def Reward in ep 096|
# |Att Loss 0.0302 | Att Reward in ep 004|
# |Def Estimated: [19 15 19 47]| Att Labels: [16 15 21 48]
#
# |Epoch 489/500| time: 49.51|
# |Def Loss 0.0356 | Def Reward in ep 098|
# |Att Loss 0.0302 | Att Reward in ep 002|
# |Def Estimated: [19 13 29 39]| Att Labels: [18 13 31 38]
#
# |Epoch 490/500| time: 51.86|
# |Def Loss 0.0355 | Def Reward in ep 099|
# |Att Loss 0.0302 | Att Reward in ep 001|
# |Def Estimated: [14 15 30 41]| Att Labels: [14 14 30 42]
#
# |Epoch 491/500| time: 48.52|
# |Def Loss 0.0355 | Def Reward in ep 097|
# |Att Loss 0.0302 | Att Reward in ep 003|
# |Def Estimated: [17 13 23 47]| Att Labels: [15 14 22 49]
#
# |Epoch 492/500| time: 47.55|
# |Def Loss 0.0354 | Def Reward in ep 092|
# |Att Loss 0.0302 | Att Reward in ep 008|
# |Def Estimated: [19 13 20 48]| Att Labels: [17 16 18 49]
#
# |Epoch 493/500| time: 48.33|
# |Def Loss 0.0354 | Def Reward in ep 097|
# |Att Loss 0.0302 | Att Reward in ep 003|
# |Def Estimated: [15 12 22 51]| Att Labels: [16 11 21 52]
#
# |Epoch 494/500| time: 49.31|
# |Def Loss 0.0353 | Def Reward in ep 096|
# |Att Loss 0.0301 | Att Reward in ep 004|
# |Def Estimated: [16 17 25 42]| Att Labels: [16 16 25 43]
#
# |Epoch 495/500| time: 48.02|
# |Def Loss 0.0352 | Def Reward in ep 095|
# |Att Loss 0.0301 | Att Reward in ep 005|
# |Def Estimated: [15 16 22 47]| Att Labels: [16 16 23 45]
#
# |Epoch 496/500| time: 47.39|
# |Def Loss 0.0352 | Def Reward in ep 099|
# |Att Loss 0.0301 | Att Reward in ep 001|
# |Def Estimated: [21 17 23 39]| Att Labels: [20 17 23 40]
#
# |Epoch 497/500| time: 49.18|
# |Def Loss 0.0352 | Def Reward in ep 096|
# |Att Loss 0.0301 | Att Reward in ep 004|
# |Def Estimated: [15 14 21 50]| Att Labels: [15 15 21 49]
#
# |Epoch 498/500| time: 47.90|
# |Def Loss 0.0351 | Def Reward in ep 094|
# |Att Loss 0.0301 | Att Reward in ep 006|
# |Def Estimated: [12 14 28 46]| Att Labels: [11 13 28 48]
#
# |Epoch 499/500| time: 46.23|
# |Def Loss 0.0351 | Def Reward in ep 097|
# |Att Loss 0.0301 | Att Reward in ep 003|
# |Def Estimated: [16 17 23 44]| Att Labels: [14 16 23 47]

# %%
if not os.path.exists('models'):
    os.makedirs('models')
# Save trained model weights and architecture, used in test
defender_agent.model_network.model.save("models/defender_agent_model.keras",overwrite=True)


if not os.path.exists('results'):
    os.makedirs('results')
# Plot training results
plt.figure(1)
plt.subplot(211)
plt.plot(np.arange(len(def_reward_chain)),def_reward_chain,label='Defense')
plt.plot(np.arange(len(att_reward_chain)),att_reward_chain,label='Attack')
plt.title('Total reward by episode')
plt.xlabel('n Episode')
plt.ylabel('Total reward')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

plt.subplot(212)
plt.plot(np.arange(len(def_loss_chain)),def_loss_chain,label='Defense')
plt.plot(np.arange(len(att_loss_chain)),att_loss_chain,label='Attack')
plt.title('Loss by episode')
plt.xlabel('n Episode')
plt.ylabel('loss')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)
plt.tight_layout()
#plt.show()
plt.savefig('results/train_adv.eps', format='eps', dpi=1000)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# --- Plot 2: Mapped 5 classes (FIXED) ---
class_names = ['Normal', 'DoS', 'Probe', 'R2L']
epochs_to_plot = [0, 10, 20, 30, 40, 60, 70, 80, 90]

plt.figure(3, figsize=[12, 10])
plt.suptitle("Mapped Attack Classes Over Time", fontsize=16)

# Safe global max
all_values = [val for epoch_data in attack_labels_list for val in epoch_data]
global_max = max(all_values) if all_values else 100

for idx, e in enumerate(epochs_to_plot):
    plt.subplot(3, 3, idx + 1)
    counts = attack_labels_list[e]
    if not isinstance(counts, (list, np.ndarray)) or len(counts) != 4:
        counts = [0, 0, 0, 0, 0]
    plt.bar(range(4), counts, tick_label=class_names, color='salmon', edgecolor='black')
    plt.title(f"Epoch {e}")
    plt.ylim(0, global_max * 1.1)
    plt.ylabel("Count")

plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('results/Attacks_mapped_distribution.svg', format='svg', dpi=1000)
plt.show()

# %%
from keras.models import model_from_json
from keras.models import load_model
import itertools
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import  confusion_matrix

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
formated_test_path = "formated_test_adv.data"
model = load_model("models/defender_agent_model.keras",custom_objects={"huber_loss": huber_loss})

model.compile(loss=huber_loss,optimizer="sgd")


# Define environment, game, make sure the batch_size is the same in train
env_test = RLenv('test',formated_test_path = formated_test_path)


total_reward = 0


true_labels = np.zeros(len(env_test.attack_types),dtype=int)
estimated_labels = np.zeros(len(env_test.attack_types),dtype=int)
estimated_correct_labels = np.zeros(len(env_test.attack_types),dtype=int)

#states , labels = env.get_sequential_batch(test_path,batch_size = env.batch_size)
states , labels = env_test.get_full()


start_time=time.time()
q = model.predict(states)
actions = np.argmax(q,axis=1)
# Out:
# 705/705 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %%
maped=[]
for indx,label in labels.iterrows():
    maped.append(env_test.attack_types.index(env_test.attack_map[label.idxmax()]))

labels,counts = np.unique(maped,return_counts=True)
true_labels[labels] += counts



for indx,a in enumerate(actions):
    estimated_labels[a] +=1
    if a == maped[indx]:
        total_reward += 1
        estimated_correct_labels[a] += 1


action_dummies = pd.get_dummies(actions)
posible_actions = np.arange(len(env_test.attack_types))
for non_existing_action in posible_actions:
    if non_existing_action not in action_dummies.columns:
        action_dummies[non_existing_action] = np.uint8(0)
labels_dummies = pd.get_dummies(maped)

normal_f1_score = f1_score(labels_dummies[0].values,action_dummies[0].values)
dos_f1_score = f1_score(labels_dummies[1].values,action_dummies[1].values)
probe_f1_score = f1_score(labels_dummies[2].values,action_dummies[2].values)
r2l_f1_score = f1_score(labels_dummies[3].values,action_dummies[3].values)



Accuracy = [normal_f1_score,dos_f1_score,probe_f1_score,r2l_f1_score]
Mismatch = estimated_labels - true_labels

acc = float(100*total_reward/len(states))
print('\r\nTotal reward: {} | Number of samples: {} | Accuracy = {:.2f}%'.format(total_reward,
      len(states),acc))
outputs_df = pd.DataFrame(index = env_test.attack_types,columns = ["Estimated","Correct","Total","F1_score"])
for indx,att in enumerate(env_test.attack_types):
   outputs_df.iloc[indx].Estimated = estimated_labels[indx]
   outputs_df.iloc[indx].Correct = estimated_correct_labels[indx]
   outputs_df.iloc[indx].Total = true_labels[indx]
   outputs_df.iloc[indx].F1_score = Accuracy[indx]*100
   outputs_df.iloc[indx].Mismatch = abs(Mismatch[indx])


print(outputs_df)
# Out:
# Total reward: 17069 | Number of samples: 22544 | Accuracy = 75.71%
#        Estimated Correct Total   F1_score
# normal     13105    9150  9912  79.506452
# DoS         7049    6156  7458  84.869373
# Probe       2010    1471  2421  66.395847
# R2L          380     292  2753  18.640281

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 6)
width = 0.35
pos = np.arange(len(true_labels))
p1 = plt.bar(pos, estimated_correct_labels,width,color='g')
p1 = plt.bar(pos+width,
             (np.abs(estimated_correct_labels-true_labels)),width,
             color='r')
p2 = plt.bar(pos+width,np.abs(estimated_labels-estimated_correct_labels),width,
             bottom=(np.abs(estimated_correct_labels-true_labels)),
             color='b')

ax.yaxis.set_tick_params(labelsize=15)
ax.set_xticks(pos+width/2)
ax.set_xticklabels(env.attack_types,rotation='vertical',fontsize = 'xx-large')

#ax.set_yscale('log')

#ax.set_ylim([0, 100])
#ax.set_title('Test set scores',fontsize = 'xx-large')
#ax.set_title('Test set scores, Acc = {:.2f}'.format(acc))
plt.legend(('Correct estimated','False negative','False positive'),fontsize = 'x-large')
plt.tight_layout()
#plt.show()
plt.savefig('results/test_adv_imp.svg', format='svg', dpi=1000)

# %%
aggregated_data_test = np.array(maped)

print('Performance measures on Test data')
print('Accuracy =  {:.4f}'.format(accuracy_score( aggregated_data_test,actions)))
print('F1 =  {:.4f}'.format(f1_score(aggregated_data_test,actions, average='weighted')))
print('Precision_score =  {:.4f}'.format(precision_score(aggregated_data_test,actions, average='weighted')))
print('recall_score =  {:.4f}'.format(recall_score(aggregated_data_test,actions, average='weighted')))

cnf_matrix = confusion_matrix(aggregated_data_test,actions)
np.set_printoptions(precision=2)
plt.figure()
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=env.attack_types, normalize=True,
                      title='Normalized confusion matrix')
plt.savefig('results/confusion_matrix_adversarial.svg', format='svg', dpi=1000)
# Out:
# Performance measures on Test data
# Accuracy =  0.7571
# F1 =  0.7244
# Precision_score =  0.7683
# recall_score =  0.7571
# Normalized confusion matrix
# [[9.23e-01 4.66e-02 2.92e-02 1.11e-03]
#  [1.46e-01 8.25e-01 2.82e-02 1.34e-04]
#  [1.84e-01 1.77e-01 6.08e-01 3.14e-02]
#  [8.78e-01 1.09e-03 1.45e-02 1.06e-01]]
